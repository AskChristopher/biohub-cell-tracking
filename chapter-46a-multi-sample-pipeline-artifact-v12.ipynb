# %% [markdown]
# # BioHub Cell Tracking During Development
# ## Chapter 46A — Multi-Sample Pipeline Artifact Generation (v12)
#
# **Purpose:** Reproduce the historical **Chapter 34 → Chapter 35 → Chapter 36 → Chapter 37** pipeline across additional training samples so the existing Chapter 46 audit can measure division failures across more than one event.
#
# ### Reproducibility contract
#
# This is an **artifact-generation / reproduction notebook**, not a model-improvement notebook.
#
# It will:
#
# - use the exact historical Chapter 34–37 notebooks as the algorithm source of truth;
# - record their SHA-256 hashes;
# - discover training samples containing at least one **binary ground-truth division**;
# - use target-sample ground truth only for **sample selection and division counting**;
# - run each selected sample independently so tracks can never cross sample boundaries;
# - preserve historical settings and thresholds;
# - add `sample_id` and globally-qualified track IDs to combined outputs;
# - report failed stages explicitly rather than silently dropping samples;
# - package all CSV artifacts into `chapter46a_multisample_pipeline_artifacts.zip`.
#
# ### Chapter 36 leakage safeguard
#
# The historical Chapter 36 notebook contains an optional supervised temporal classifier. Chapter 46A **must not re-train that classifier on each new target sample**. If a frozen historical model is available, it may be applied unchanged. Otherwise, Chapter 46A uses the historical **label-free temporal support score** and records that mode in the validation table. No new target sample is used to fit a Chapter 36 model.
#
# ### Required outputs
#
# - `chapter34_top200_detections_multisample.csv`
# - `chapter35_track_nodes_multisample.csv`
# - `chapter35_track_edges_multisample.csv`
# - `chapter35_track_summary_multisample.csv`
# - `chapter36_filtered_detections_multisample.csv`
# - `chapter36_filtered_track_nodes_multisample.csv`
# - `chapter36_filtered_track_edges_multisample.csv`
# - `chapter37_refined_track_nodes_multisample.csv`
# - `chapter37_refined_track_edges_multisample.csv`
# - `chapter37_refined_track_summary_multisample.csv`
# - `chapter46a_sample_summary.csv`
# - `chapter46a_validation.csv`
# - `chapter46a_failures.csv`
# - `chapter46a_selected_samples.csv`
# - `chapter46a_source_manifest.csv`
# - `chapter46a_multisample_pipeline_artifacts.zip`
#
# > **v2 fix:** GT sample discovery now uses the same Zarr-backed `load_geff_tables()` structure as the existing Chapter 46 audit, replacing the incorrect generic JSON GEFF parser.
#
# > **v3 fix:** historical notebook replay now executes inside real module-backed namespaces registered in `sys.modules`. This fixes the Python 3.12 `@dataclass` replay error seen while bootstrapping Chapter 34, without modifying Chapter 34's algorithm.
#
# > **v4 fix:** Chapter 34 replay no longer assumes globals named `model` and `feature_columns`. It inspects the actual historical `run_detection_pipeline()` signature and resolves only what that function requires.
#
# > **v5 fix:** historical definition replay now extracts functions, classes, imports, constants, and `CONFIG = *Config(...)` assignments from mixed notebook cells individually. This prevents reusable functions such as Chapter 35's `track_sequence()` from being skipped just because their cell also contains top-level notebook execution code.
#
# > **v6 smoke-test fix:** runs only one selected sample by default and supplies Chapter 34 with the actual historical inputs: the sample microscopy `raw_volume`, frozen ranking model, historical feature columns, all timepoints, and a sample-specific `DetectionConfig`. The final cell reports failure instead of raising, so a smoke test cannot waste a full-cohort run.
#
# > **v7 fix:** Chapter 34 model discovery now rejects imported estimator classes and selects only a fitted estimator instance. V6 mistakenly selected the `HistGradientBoostingRegressor` class itself, causing the unbound `predict()` TypeError.
#
# > **v8 fix:** Chapter 34 now derives its feature schema from the fitted historical model's `feature_names_in_` whenever available. V7 recovered the correct fitted model but paired it with the wrong historical feature-list variable, producing a feature-name mismatch.
#
# > **v9 fix:** V8 contained a second assignment that accidentally overwrote the feature list recovered from the fitted estimator's `feature_names_in_` with `GRAPH_FEATURE_COLUMNS`. V9 removes that overwrite, treats the fitted estimator as the feature-schema source of truth, and adds a fail-fast equality preflight before any expensive image processing.
#
# > **v10 fix:** V9 completed Chapter 34 across all 100 timepoints, but Chapter 46A rejected the historical pipeline's dict return type. V10 leaves Chapter 34 unchanged, logs the returned dict keys, and extracts the existing detection DataFrame by semantic key or unambiguous detection-like schema before continuing to Chapter 35.
#
# > **v11 fix:** V10 confirmed that Chapter 34 now completes all 100 timepoints and yields 20,000 selected detections, but Chapter 35's historical `track_sequence()` returns a dict (`track_nodes`, `track_edges`, `frame_summary`) rather than the tuple expected by the reproduction harness. V11 adds an orchestration-only tracking-result adapter, preserves the historical tracker unchanged, and adds defensive dict/schema handling around downstream stage outputs so another expensive smoke test is less likely to stop on a return-shape mismatch.
#
# > **v12 mini-batch / restart fix:** V11 completed the full Chapter 34→35→36→37 pipeline for one sample with no stage failures. V12 expands the reliability test to **three selected samples** and adds per-stage checkpoint reuse. If a stage's expected per-sample CSV artifacts already exist, V12 reloads them instead of recomputing that stage. Failures are flushed immediately to `chapter46a_failures.csv`, so a later-stage edge case does not erase earlier completed work. Historical algorithms, models, thresholds, and Chapter 36 leakage safeguards remain unchanged.

# %%
# !pip install -q zarr networkx scipy scikit-learn nbformat

# %%
from __future__ import annotations

from dataclasses import dataclass, replace
from pathlib import Path
from typing import Any, Optional
import ast
import inspect
import sys
import types
import hashlib
import json
import re
import traceback
import urllib.request
import zipfile
import warnings

import nbformat
import networkx as nx
import numpy as np
import pandas as pd
import zarr

from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cdist
from IPython.display import display

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 180)

# %% [markdown]
# ## 1. Configuration

# %%
@dataclass(frozen=True)
class Config:
    competition_dir: Path = Path(
        "/kaggle/input/competitions/biohub-cell-tracking-during-development"
    )
    output_dir: Path = Path("/kaggle/working/chapter46a")
    source_dir: Path = Path("/kaggle/working/chapter46a/historical_sources")
    per_sample_dir: Path = Path("/kaggle/working/chapter46a/per_sample")

    repo_owner: str = "AskChristopher"
    repo_name: str = "biohub-cell-tracking"
    repo_branch: str = "main"

    historical_sample_id: str = "44b6_12dfb391"

    source_notebooks: tuple[str, ...] = (
        "chapter-34-end-to-end-detection-pipeline.ipynb",
        "chapter-35-motion-aware-tracking-with-gap-closin.ipynb",
        "chapter-36-track-aware-detection-filtering.ipynb",
        "chapter-37-track-refinement-and-gap-closing.ipynb",
    )

    strict_complete: bool = False

    # V12 reliability mini-batch. Use None only after the 3-sample run passes.
    max_selected_samples: Optional[int] = 3

    # Reuse completed per-stage CSV artifacts when rerunning in the same Kaggle workspace.
    reuse_stage_checkpoints: bool = True

CONFIG = Config()
CONFIG.output_dir.mkdir(parents=True, exist_ok=True)
CONFIG.source_dir.mkdir(parents=True, exist_ok=True)
CONFIG.per_sample_dir.mkdir(parents=True, exist_ok=True)
CONFIG
# Out:
# Config(competition_dir=PosixPath('/kaggle/input/competitions/biohub-cell-tracking-during-development'), output_dir=PosixPath('/kaggle/working/chapter46a'), source_dir=PosixPath('/kaggle/working/chapter46a/historical_sources'), per_sample_dir=PosixPath('/kaggle/working/chapter46a/per_sample'), repo_owner='AskChristopher', repo_name='biohub-cell-tracking', repo_branch='main', historical_sample_id='44b6_12dfb391', source_notebooks=('chapter-34-end-to-end-detection-pipeline.ipynb', 'chapter-35-motion-aware-tracking-with-gap-closin.ipynb', 'chapter-36-track-aware-detection-filtering.ipynb', 'chapter-37-track-refinement-and-gap-closing.ipynb'), strict_complete=False, max_selected_samples=3, reuse_stage_checkpoints=True)

# %% [markdown]
# ## 2. Acquire the exact historical Chapter 34–37 source notebooks
#
# The notebook first searches attached Kaggle inputs for exact filenames. If a source notebook is not attached, it downloads the public repository copy. A SHA-256 manifest is saved for provenance.

# %%
def sha256_file(path: Path) -> str:
    h = hashlib.sha256()
    with path.open("rb") as f:
        for chunk in iter(lambda: f.read(1024 * 1024), b""):
            h.update(chunk)
    return h.hexdigest()


def find_attached_notebook(filename: str) -> Optional[Path]:
    root = Path("/kaggle/input")
    if not root.exists():
        return None
    matches = list(root.rglob(filename))
    return matches[0] if matches else None


def github_raw_url(filename: str) -> str:
    return (
        f"https://raw.githubusercontent.com/"
        f"{CONFIG.repo_owner}/{CONFIG.repo_name}/"
        f"{CONFIG.repo_branch}/{filename}"
    )


def acquire_source(filename: str) -> tuple[Path, str]:
    target = CONFIG.source_dir / filename
    attached = find_attached_notebook(filename)

    if attached is not None:
        target.write_bytes(attached.read_bytes())
        return target, f"kaggle_input:{attached}"

    url = github_raw_url(filename)
    try:
        urllib.request.urlretrieve(url, target)
        return target, f"github:{url}"
    except Exception as exc:
        raise FileNotFoundError(
            f"Could not acquire {filename}. Attach the four historical notebooks "
            "as a Kaggle Dataset or enable Internet. "
            f"Download error: {exc}"
        ) from exc


SOURCE_PATHS = {}
source_rows = []

for filename in CONFIG.source_notebooks:
    path, source = acquire_source(filename)
    SOURCE_PATHS[filename] = path
    source_rows.append(
        {
            "filename": filename,
            "source": source,
            "sha256": sha256_file(path),
            "bytes": path.stat().st_size,
        }
    )

source_manifest = pd.DataFrame(source_rows)
source_manifest.to_csv(
    CONFIG.output_dir / "chapter46a_source_manifest.csv", index=False
)
display(source_manifest)
# Out:
#                                             filename                                             source                                             sha256    bytes
# 0     chapter-34-end-to-end-detection-pipeline.ipynb  github:https://raw.githubusercontent.com/AskCh...  e41c9c86f78a941097a12af2119d9c2aabfef840316f0f...  1870995
# 1  chapter-35-motion-aware-tracking-with-gap-clos...  github:https://raw.githubusercontent.com/AskCh...  d562295be3459a4b14f5f7e4897942b3cecb4a16dbb070...   383505
# 2   chapter-36-track-aware-detection-filtering.ipynb  github:https://raw.githubusercontent.com/AskCh...  c5b8711fe79bdfc21ec3784fbaa15bac7edf27ec2fb3f1...   182364
# 3  chapter-37-track-refinement-and-gap-closing.ipynb  github:https://raw.githubusercontent.com/AskCh...  4321d296ad2fc4a43833f04e84756a7f87d020fd9b8a3b...   424984

# %% [markdown]
# ## 3. Discover binary GT divisions and freeze the target cohort
#
# A binary division is a GT graph node with **exactly two outgoing edges**.
#
# Ground truth is used only in this section to select samples and count divisions. After `selected_samples` is created, the new target cohort is frozen and target GT is not consulted by Chapters 34–37.

# %%
def find_train_dir() -> Path:
    for candidate in (
        CONFIG.competition_dir / "train",
        CONFIG.competition_dir / "training",
    ):
        if candidate.exists():
            return candidate

    geff = list(CONFIG.competition_dir.rglob("*.geff"))
    if geff:
        return geff[0].parent

    raise FileNotFoundError(
        f"Could not locate training GEFF data below {CONFIG.competition_dir}"
    )


TRAIN_DIR = find_train_dir()
print("Training directory:", TRAIN_DIR)


def sample_id_from_geff(path: Path) -> str:
    return path.name[:-5] if path.name.endswith(".geff") else path.stem


def load_geff_tables(geff_path: Path):
    """
    Proven GEFF loader copied from the existing Chapter 46 audit.

    BioHub GEFF samples are Zarr stores. The node table is stored under:
      nodes/ids
      nodes/props/t/values
      nodes/props/z/values
      nodes/props/y/values
      nodes/props/x/values

    Edges are stored under:
      edges/ids

    Ground truth loaded here is used ONLY to select samples and count divisions.
    """
    geff = zarr.open(geff_path, mode="r")

    nodes = pd.DataFrame({
        "gt_node_id": np.asarray(geff["nodes/ids"][:]),
        "t": np.asarray(geff["nodes/props/t/values"][:]).astype(int),
        "z": np.asarray(geff["nodes/props/z/values"][:]).astype(float),
        "y": np.asarray(geff["nodes/props/y/values"][:]).astype(float),
        "x": np.asarray(geff["nodes/props/x/values"][:]).astype(float),
    })

    edge_ids = np.asarray(geff["edges/ids"][:])

    edges = pd.DataFrame({
        "gt_source": edge_ids[:, 0],
        "gt_target": edge_ids[:, 1],
    })

    return nodes, edges


def count_binary_divisions(sample_id: str, geff_path: Path):
    """
    Count GT binary divisions exactly as Chapter 46 does:
    parent node out-degree == 2.

    Also record out-degree > 2 events separately.
    """
    nodes, edges = load_geff_tables(geff_path)

    out_degree = edges.groupby("gt_source").size()

    binary_parents = out_degree[out_degree == 2]
    unusual_parents = out_degree[out_degree > 2]

    return {
        "sample_id": sample_id,
        "gt_binary_divisions": int(len(binary_parents)),
        "gt_outdegree_gt2_events": int(len(unusual_parents)),
        "geff_path": str(geff_path),
        "selection_error": "",
    }, [
        {
            "sample_id": sample_id,
            "parent_gt_id": parent_id,
            "out_degree": int(degree),
        }
        for parent_id, degree in unusual_parents.items()
    ]


geff_paths = sorted(TRAIN_DIR.glob("*.geff"))

if not geff_paths:
    geff_paths = sorted(TRAIN_DIR.rglob("*.geff"))

if not geff_paths:
    raise FileNotFoundError(
        f"No .geff samples found under {TRAIN_DIR}"
    )


division_rows = []
unusual_rows = []

for geff_path in geff_paths:
    sample_id = sample_id_from_geff(geff_path)

    try:
        row, unusual = count_binary_divisions(
            sample_id,
            geff_path,
        )
        division_rows.append(row)
        unusual_rows.extend(unusual)

    except Exception as exc:
        division_rows.append({
            "sample_id": sample_id,
            "gt_binary_divisions": np.nan,
            "gt_outdegree_gt2_events": np.nan,
            "geff_path": str(geff_path),
            "selection_error": f"{type(exc).__name__}: {exc}",
        })


division_counts = pd.DataFrame(division_rows)

selected_samples = (
    division_counts[
        (division_counts["selection_error"] == "")
        & (division_counts["gt_binary_divisions"] >= 1)
    ]
    .sort_values(
        ["gt_binary_divisions", "sample_id"],
        ascending=[False, True],
    )
    .reset_index(drop=True)
)

if CONFIG.max_selected_samples is not None:
    selected_samples = selected_samples.head(
        CONFIG.max_selected_samples
    ).copy()


selected_samples.to_csv(
    CONFIG.output_dir / "chapter46a_selected_samples.csv",
    index=False,
)

pd.DataFrame(unusual_rows).to_csv(
    CONFIG.output_dir / "chapter46a_unusual_gt_branching.csv",
    index=False,
)


failed_gt_reads = division_counts[
    division_counts["selection_error"] != ""
].copy()

print("Training samples discovered:", len(division_counts))
print(
    "Samples whose GEFF GT loaded successfully:",
    int((division_counts["selection_error"] == "").sum()),
)
print(
    "Samples whose GEFF GT failed to load:",
    len(failed_gt_reads),
)
print(
    "Selected samples with >=1 binary GT division:",
    len(selected_samples),
)

display(selected_samples)

if len(failed_gt_reads):
    print("\nGEFF read failures (first 10):")
    display(
        failed_gt_reads[
            ["sample_id", "selection_error"]
        ].head(10)
    )


# Sanity check against the known historical division sample.
known = division_counts[
    division_counts["sample_id"].astype(str)
    == CONFIG.historical_sample_id
]

if len(known) != 1:
    raise RuntimeError(
        "Known historical sample "
        f"{CONFIG.historical_sample_id!r} was not found exactly once."
    )

known_binary_count = known.iloc[0]["gt_binary_divisions"]
known_error = known.iloc[0]["selection_error"]

print(
    "\nKnown historical sample sanity check:",
    CONFIG.historical_sample_id,
    "| binary GT divisions:",
    known_binary_count,
    "| error:",
    known_error or "none",
)

if known_error:
    raise RuntimeError(
        "The proven GEFF loader could not read the known historical sample. "
        f"Error: {known_error}"
    )

if int(known_binary_count) < 1:
    raise RuntimeError(
        "GEFF discovery sanity check failed: the known historical sample "
        f"{CONFIG.historical_sample_id} should contain at least one binary division."
    )

if selected_samples.empty:
    raise RuntimeError(
        "No samples with binary GT divisions were discovered even though "
        "the GEFF loader passed the known-sample sanity check."
    )

print(
    "\nGT discovery passed. The target cohort is now frozen. "
    "Chapters 34–37 will not use target-sample GT."
)
# Out:
# Training directory: /kaggle/input/competitions/biohub-cell-tracking-during-development/train
# Training samples discovered: 199
# Samples whose GEFF GT loaded successfully: 199
# Samples whose GEFF GT failed to load: 0
# Selected samples with >=1 binary GT division: 3
#        sample_id  gt_binary_divisions  gt_outdegree_gt2_events                                          geff_path selection_error
# 0  6bba_48816121                    5                        0  /kaggle/input/competitions/biohub-cell-trackin...
# 1  6bba_09961292                    4                        0  /kaggle/input/competitions/biohub-cell-trackin...
# 2  6bba_afb141ff                    4                        0  /kaggle/input/competitions/biohub-cell-trackin...
# Known historical sample sanity check: 44b6_12dfb391 | binary GT divisions: 1 | error: none
#
# GT discovery passed. The target cohort is now frozen. Chapters 34–37 will not use target-sample GT.

# %% [markdown]
# ## 4. Historical source execution helpers
#
# These helpers reuse algorithm cells from the historical notebooks. Only orchestration-level changes are allowed: input paths, output directories, sample ID, and skipping target-GT evaluation/training sections.

# %%
def load_nb(path: Path):
    return nbformat.read(path, as_version=4)


def clean_ipython_code(source: str) -> str:
    # Dependencies are installed by Chapter 46A.
    # Shell/magic lines cannot be compiled with Python exec().
    kept = []
    for line in source.splitlines():
        stripped = line.lstrip()
        if stripped.startswith("!") or stripped.startswith("%"):
            continue
        kept.append(line)
    return "\n".join(kept)


def section_map(nb):
    sections = []
    heading = "__preamble__"
    code_cells = []

    def flush():
        nonlocal code_cells
        if code_cells:
            sections.append((heading, code_cells))
            code_cells = []

    for cell in nb.cells:
        if cell.cell_type == "markdown":
            hs = [
                x.strip()
                for x in cell.source.splitlines()
                if x.strip().startswith("## ")
            ]
            if hs:
                flush()
                heading = hs[-1]
        elif cell.cell_type == "code":
            code_cells.append(cell.source)

    flush()
    return sections


def exec_code(source: str, ns: dict[str, Any], label: str):
    source = clean_ipython_code(source)
    if not source.strip():
        return
    try:
        exec(compile(source, label, "exec"), ns, ns)
    except Exception as exc:
        raise RuntimeError(
            f"{label}: {type(exc).__name__}: {exc}"
        ) from exc


def make_exec_namespace(module_name: str) -> dict[str, Any]:
    module = types.ModuleType(module_name)
    sys.modules[module_name] = module
    ns = module.__dict__
    ns.update({"Path": Path, "np": np, "pd": pd, "zarr": zarr, "nx": nx,
               "linear_sum_assignment": linear_sum_assignment, "cdist": cdist,
               "display": display})
    return ns


def _literal_only(node):
    if isinstance(node, ast.Constant): return True
    if isinstance(node,(ast.List,ast.Tuple,ast.Set)): return all(_literal_only(x) for x in node.elts)
    if isinstance(node,ast.Dict): return all((k is None or _literal_only(k)) and _literal_only(v) for k,v in zip(node.keys,node.values))
    if isinstance(node,ast.UnaryOp): return _literal_only(node.operand)
    if isinstance(node,ast.BinOp): return _literal_only(node.left) and _literal_only(node.right)
    return False


def _assignment_names(node):
    targets=node.targets if isinstance(node,ast.Assign) else [node.target]
    return [t.id for t in targets if isinstance(t,ast.Name)]


def bootstrap_definition_cells(nb, label: str) -> dict[str, Any]:
    ns=make_exec_namespace(f"__{label}_defs__")
    imports=[]; classes=[]; literals=[]; configs=[]; functions=[]
    for heading,sources in section_map(nb):
        for source in sources:
            cleaned=clean_ipython_code(source)
            if not cleaned.strip(): continue
            try: tree=ast.parse(cleaned)
            except SyntaxError: continue
            for node in tree.body:
                if isinstance(node,ast.Import): imports.append(node); continue
                if isinstance(node,ast.ImportFrom):
                    if node.module!='__future__': imports.append(node)
                    continue
                if isinstance(node,ast.ClassDef): classes.append(node); continue
                if isinstance(node,(ast.FunctionDef,ast.AsyncFunctionDef)): functions.append(node); continue
                if isinstance(node,(ast.Assign,ast.AnnAssign)):
                    names=_assignment_names(node); value=node.value
                    if _literal_only(value): literals.append(node); continue
                    if 'CONFIG' in names and isinstance(value,ast.Call):
                        func=value.func
                        if isinstance(func,ast.Name) and func.id.lower().endswith('config'):
                            configs.append(node); continue
    synthetic=ast.Module(body=imports+literals+classes+configs+functions,type_ignores=[])
    ast.fix_missing_locations(synthetic)
    try:
        exec(compile(synthetic,f"<{label}-historical-definitions>",'exec'),ns,ns)
    except Exception as exc:
        raise RuntimeError(f"Could not bootstrap reusable definitions for {label}: {type(exc).__name__}: {exc}") from exc
    return ns


def run_heading_sections(
    nb,
    ns: dict[str, Any],
    include_patterns: list[str],
    skip_patterns: list[str] | None = None,
):
    skip_patterns = skip_patterns or []

    for heading, sources in section_map(nb):
        if not any(
            re.search(p, heading, flags=re.I)
            for p in include_patterns
        ):
            continue

        if any(
            re.search(p, heading, flags=re.I)
            for p in skip_patterns
        ):
            continue

        for i, source in enumerate(sources):
            exec_code(
                source,
                ns,
                f"{heading} / cell {i}",
            )


def qualify_track_ids(df: pd.DataFrame, sample_id: str) -> pd.DataFrame:
    out = df.copy()
    if "sample_id" not in out.columns:
        out.insert(0, "sample_id", sample_id)

    for col in (
        "track_id",
        "source_track_id",
        "target_track_id",
        "parent_track_id",
        "daughter_track_id",
    ):
        if col in out.columns:
            out[f"global_{col}"] = (
                sample_id + "::" + out[col].astype(str)
            )

    return out

# %% [markdown]
# ## 5. Bootstrap the historical Chapter 34 detector
#
# The historical Chapter 34 source defines a reusable `run_detection_pipeline(sample_id, model, feature_columns)` function. Chapter 46A reconstructs that detector state from the original source once, then applies it unchanged to the frozen target cohort.
#
# If the current historical source no longer exposes those objects, the notebook stops rather than inventing a replacement detector.

# %%
CH34_NAME = "chapter-34-end-to-end-detection-pipeline.ipynb"
ch34_nb = load_nb(SOURCE_PATHS[CH34_NAME])
CH34_NS = make_exec_namespace("__chapter34_replay__")

for heading, sources in section_map(ch34_nb):
    if re.search(r"(plot|visuali[sz]|conclusion|next step)", heading, flags=re.I):
        continue
    for i, source in enumerate(sources):
        try:
            exec_code(source, CH34_NS, f"Chapter 34 / {heading} / {i}")
        except RuntimeError as exc:
            if "run_detection_pipeline" in CH34_NS:
                warnings.warn("Chapter 34 replay hit a later-cell error after run_detection_pipeline() was defined: " + str(exc))
                continue
            raise

if "run_detection_pipeline" not in CH34_NS:
    raise RuntimeError("Historical Chapter 34 did not expose run_detection_pipeline().")
run_detection_pipeline = CH34_NS["run_detection_pipeline"]
CH34_SIGNATURE = inspect.signature(run_detection_pipeline)
print("Historical Chapter 34 pipeline function loaded.")
print("Signature:", CH34_SIGNATURE)


def _looks_like_fitted_estimator(obj):
    """
    Reject estimator classes and prefer fitted estimator *instances*.

    V6 accidentally selected the imported HistGradientBoostingRegressor class
    itself because classes expose a predict method. Calling that unbound method
    produced:
        TypeError: HistGradientBoostingRegressor.predict()
        missing 1 required positional argument: 'X'
    """
    if obj is None or inspect.isclass(obj):
        return False

    if not (hasattr(obj, "predict") or hasattr(obj, "predict_proba")):
        return False

    # Scikit-learn fitted estimators normally acquire attributes ending in "_".
    fitted_attrs = [
        name
        for name in dir(obj)
        if name.endswith("_") and not name.startswith("__")
    ]

    return len(fitted_attrs) > 0


def _find_model_candidate(namespace):
    preferred = [
        "model",
        "best_model",
        "distance_model",
        "hist_model",
        "hist_distance_model",
        "ranking_model",
        "regressor",
        "rank_model",
        "detector_model",
    ]

    # First try likely historical variable names.
    for name in preferred:
        obj = namespace.get(name)
        if _looks_like_fitted_estimator(obj):
            return name, obj

    # Then inspect all namespace objects, but NEVER return an estimator class.
    candidates = []

    for name, obj in namespace.items():
        if name.startswith("_"):
            continue

        if not _looks_like_fitted_estimator(obj):
            continue

        fitted_attrs = [
            x
            for x in dir(obj)
            if x.endswith("_") and not x.startswith("__")
        ]

        candidates.append(
            (len(fitted_attrs), name, obj)
        )

    if candidates:
        # Prefer the object with the richest fitted state.
        candidates.sort(reverse=True, key=lambda x: x[0])
        _, name, obj = candidates[0]
        return name, obj

    return None, None


def _find_feature_columns_candidate(namespace):
    preferred=["feature_columns","FEATURE_COLUMNS","features","model_features","feature_names","training_features","GRAPH_FEATURE_COLUMNS"]
    for name in preferred:
        obj=namespace.get(name)
        if isinstance(obj,(list,tuple)) and obj and all(isinstance(x,str) for x in obj): return name,list(obj)
    for name,obj in namespace.items():
        if 'feature' in name.lower() and isinstance(obj,(list,tuple)) and obj and all(isinstance(x,str) for x in obj): return name,list(obj)
    return None,None

CH34_MODEL_NAME, CH34_MODEL = _find_model_candidate(CH34_NS)

# V9: fix the V8 orchestration bug.
# V8 correctly read model.feature_names_in_ and then accidentally overwrote
# CH34_FEATURE_COLUMNS on the next line with a guessed historical list.
# The fitted estimator is the single source of truth whenever it exposes
# feature_names_in_.
if CH34_MODEL is None:
    raise RuntimeError("Could not recover frozen historical Chapter 34 ranking model.")

CH34_FALLBACK_FEATURE_NAME, CH34_FALLBACK_FEATURE_COLUMNS = _find_feature_columns_candidate(CH34_NS)

if hasattr(CH34_MODEL, "feature_names_in_"):
    CH34_FEATURE_COLUMNS_NAME = "model.feature_names_in_"
    CH34_FEATURE_COLUMNS = [str(x) for x in CH34_MODEL.feature_names_in_]
else:
    CH34_FEATURE_COLUMNS_NAME = CH34_FALLBACK_FEATURE_NAME
    CH34_FEATURE_COLUMNS = CH34_FALLBACK_FEATURE_COLUMNS

if CH34_FEATURE_COLUMNS is None:
    raise RuntimeError("Could not recover historical Chapter 34 feature columns.")

MODEL_FEATURE_NAMES = (
    [str(x) for x in CH34_MODEL.feature_names_in_]
    if hasattr(CH34_MODEL, "feature_names_in_")
    else None
)

print("Detected ranking model:", CH34_MODEL_NAME)
print("Ranking model Python type:", type(CH34_MODEL).__name__)
print("Ranking model is class:", inspect.isclass(CH34_MODEL))
print("Feature schema source:", CH34_FEATURE_COLUMNS_NAME)
print("Resolved feature count:", len(CH34_FEATURE_COLUMNS))
print("Resolved features:", CH34_FEATURE_COLUMNS)
print("Fallback historical feature variable:", CH34_FALLBACK_FEATURE_NAME)
print("Fallback historical features:", CH34_FALLBACK_FEATURE_COLUMNS)
print("Estimator feature_names_in_:", MODEL_FEATURE_NAMES)

# Fail immediately if our adapter somehow diverges from the fitted estimator.
if MODEL_FEATURE_NAMES is not None and CH34_FEATURE_COLUMNS != MODEL_FEATURE_NAMES:
    raise RuntimeError(
        "Chapter 34 preflight failed before image processing: resolved feature "
        "columns do not exactly match the fitted estimator's feature_names_in_."
    )

print("✓ Chapter 34 model/feature-schema preflight passed.")


def _find_sample_zarr(sample_id: str) -> Path:
    for p in [TRAIN_DIR/f"{sample_id}.zarr", CONFIG.competition_dir/'train'/f"{sample_id}.zarr", CONFIG.competition_dir/'training'/f"{sample_id}.zarr"]:
        if p.exists(): return p
    matches=list(CONFIG.competition_dir.rglob(f"{sample_id}.zarr"))
    if matches: return matches[0]
    raise FileNotFoundError(f"Could not locate microscopy Zarr volume for sample {sample_id}.")


def _open_4d_volume(path: Path):
    root=zarr.open(path,mode='r')
    if hasattr(root,'ndim') and getattr(root,'ndim',None)==4: return root
    found=[]
    def visit(group,prefix=''):
        try:
            for key in group.array_keys():
                arr=group[key]
                if getattr(arr,'ndim',None)==4: found.append((prefix+key,arr))
            for key in group.group_keys(): visit(group[key],prefix+key+'/')
        except Exception: pass
    visit(root)
    if not found: raise RuntimeError(f"No 4-D microscopy array found inside {path}.")
    if len(found)>1: print('Multiple 4-D arrays found; using:',found[0][0])
    return found[0][1]


def _make_detection_config(sample_id: str):
    DetectionConfig=CH34_NS.get('DetectionConfig')
    if DetectionConfig is None: raise RuntimeError('Historical Chapter 34 DetectionConfig was not recovered.')
    try: return DetectionConfig(sample_id=sample_id)
    except TypeError:
        base=CH34_NS.get('CONFIG')
        if base is None: raise
        return replace(base,sample_id=sample_id)


def run_ch34_for_sample(sample_id: str):
    zarr_path=_find_sample_zarr(sample_id)
    raw_volume=_open_4d_volume(zarr_path)
    if len(raw_volume.shape)!=4: raise RuntimeError(f"Expected 4-D volume; got {raw_volume.shape}")
    timepoints=range(int(raw_volume.shape[0]))
    config=_make_detection_config(sample_id)
    checkpoint_dir=CONFIG.per_sample_dir/sample_id/'chapter34_checkpoints'
    checkpoint_dir.mkdir(parents=True,exist_ok=True)
    print('Ch34 sample:',sample_id)
    print('  zarr:',zarr_path)
    print('  raw volume shape:',raw_volume.shape)
    print('  timepoints:',raw_volume.shape[0])
    print('  config sample_id:',getattr(config,'sample_id',None))
    return run_detection_pipeline(raw_volume, CH34_MODEL, CH34_FEATURE_COLUMNS, timepoints,
                                  config=config, top_k=200,
                                  checkpoint_directory=checkpoint_dir)
# Out:
# DetectionConfig(sample_id='44b6_12dfb391', nms_radius=3.0, oracle_radius=6.0, target_distance_clip=20.0, graph_radius_physical=12.0, max_graph_neighbors=16, patch_radius_2d=4, patch_radius_z=2, patch_radius_xy=4, top_k=200, train_timesteps=(0, 8, 20, 40), validation_timesteps=(60, 80), coordinate_scale_zyx=(1.625, 0.40625, 0.40625))
# Image path: /kaggle/input/competitions/biohub-cell-tracking-during-development/train/44b6_12dfb391.zarr
# GEFF path: /kaggle/input/competitions/biohub-cell-tracking-during-development/train/44b6_12dfb391.geff
# Image shape: (100, 64, 256, 256)
# Image dtype: uint16
# GT nodes: 788
#         node_id  t   z    y    x
# 0  106000000037  0  35   61  189
# 1  106000000040  0  15  194   55
# 2  106000000041  0   7  239   56
# 3  106000000043  0  27  211  109
# 4  106000000056  0  40  127  130
# t=0: raw=7795, rankable=1768, oracle_good=31, time=6.6s
# t=8: raw=7696, rankable=1823, oracle_good=32, time=6.5s
# t=20: raw=7968, rankable=1859, oracle_good=31, time=6.8s
# t=40: raw=8022, rankable=1941, oracle_good=35, time=6.8s
# Training rows: 7391
#     t  raw_candidates  rankable_candidates  oracle_good_candidates  proposal_gt_recall  elapsed_seconds
# 0   0            7795                 1768                      31                 1.0         6.631640
# 1   8            7696                 1823                      32                 1.0         6.503354
# 2  20            7968                 1859                      31                 1.0         6.822657
# 3  40            8022                 1941                      35                 1.0         6.833441
#     z    y    x  sigma  proposal_count                                   proposal_sources  proposal_peak_intensity  center_intensity   patch_mean  patch_max   patch_std  \
# 0  48   86  128  3.250               4  large_sensitive|medium_sensitive|medium_strict...                   3140.0            3140.0  2135.111084     3140.0  671.388611
# 1  55   81  255  3.625               4  large_sensitive|medium_sensitive|medium_strict...                   3013.0            3013.0  2453.733398     3013.0  341.650726
# 2  53  183  224  3.750               4  large_sensitive|medium_sensitive|medium_strict...                   2721.0            2721.0  2086.185303     2721.0  372.735138
# 3  56   10  255  3.250               4  large_sensitive|medium_sensitive|medium_strict...                   2346.0            2346.0  1821.955566     2346.0  285.270233
# 4  28  170   53  3.250               4  large_sensitive|medium_sensitive|medium_strict...                   2288.0            2288.0  1744.012329     2288.0  311.872192
#
#    local_contrast  center_to_patch_max_dist  patch_com_offset  is_near_border  center_voxel     vol_mean     vol_std  vol_max  z_line_mean  z_line_std  z_line_max  \
# 0     1004.888916                       0.0          0.203683               0        3140.0  1809.446899  658.314575   3140.0  2513.800049  558.484863      3140.0
# 1      559.266602                       2.0          0.161669               1        3013.0  2235.088867  638.692200   3517.0  2698.000000  704.911072      3388.0
# 2      634.814697                       0.0          0.035425               0        2721.0  1894.185181  433.850555   2734.0  2416.600098  234.425766      2721.0
# 3      524.044434                       2.0          0.150015               1        2346.0  1767.640015  265.910980   2346.0  2051.000000  250.521057      2346.0
# 4      543.987671                       0.0          0.141893               0        2288.0  1438.604980  359.430237   2288.0  1812.000000  358.675903      2288.0
#
#    center_over_vol_mean  center_minus_vol_mean  center_slice_minus_neighbor_mean  slice_mean_std  z_peak_offset  mass_center_offset_3d  peak_to_mean_ratio  bright_fraction  \
# 0              1.735337            1330.553101                        165.252930      379.372437              0               0.275548            1.735337         0.496296
# 1              1.348045             777.911133                        134.744629      541.989990              2               1.931775            1.573539         0.511111
# 2              1.436502             826.814819                        101.808838      195.754013              1               0.100649            1.443365         0.518519
# 3              1.327193             578.359985                         27.688965      146.235489              0               1.923731            1.327193         0.528889
# 4              1.590430             849.395020                        196.376587      236.075500              0               0.175454            1.590430         0.498765
#
#    graph_neighbor_count  graph_mean_neighbor_distance  graph_min_neighbor_distance  graph_mean_neighbor_intensity  graph_mean_neighbor_contrast  \
# 0                   9.0                      8.831360                     4.958913                    1498.444458                    319.792847
# 1                  14.0                      8.727782                     4.942245                    1789.857178                    334.454498
# 2                  14.0                      7.672420                     2.333729                    1944.428589                    445.109406
# 3                  16.0                      7.837432                     3.275292                    1871.812500                    298.832336
# 4                  16.0                      8.388052                     3.447145                    1720.812500                    309.719910
#
#    graph_mean_neighbor_proposal_count  t  nearest_gt_dist  target_dist  oracle_good
# 0                            1.666667  0        41.821049         20.0        False
# 1                            1.857143  0        71.805290         20.0        False
# 2                            1.571429  0       110.186203         20.0        False
# 3                            1.500000  0        86.011627         20.0        False
# 4                            1.562500  0        27.367865         20.0        False
# Training MAE: 0.7343918386091896
# t=60: raw=9146, nms=2221, ranked=2221, selected=200, time=7.3s
# t=80: raw=10040, nms=2460, ranked=2460, selected=200, time=7.7s
#     t  raw_candidates  nms_candidates  ranked_candidates  selected_candidates  graph_edges  elapsed_seconds
# 0  60            9146            2221               2221                  200        31517         7.305756
# 1  80           10040            2460               2460                  200        35404         7.728478
#     z    y   x  sigma  proposal_count                proposal_sources  proposal_peak_intensity  center_intensity   patch_mean  patch_max   patch_std  local_contrast  \
# 0  12  236  36   3.75               2  medium_sensitive|medium_strict                   1467.0            1467.0  1282.086426     1481.0  125.767693      198.913574
# 1  12  243  37   2.50               1                 small_sensitive                   1264.0            1264.0  1201.802490     1385.0  151.292648      183.197510
# 2  11  244  40   2.50               1                 small_sensitive                   1417.0            1417.0  1296.172852     1495.0  137.752487      198.827148
# 3  15  241  34   5.00               1                 large_sensitive                   1435.0            1435.0  1361.283936     1542.0   92.002846      180.716064
# 4  11  239  38   5.00               1                 large_sensitive                   1376.0            1376.0  1355.382690     1495.0   82.395546      139.617310
#
#    center_to_patch_max_dist  patch_com_offset  is_near_border  center_voxel     vol_mean     vol_std  vol_max  z_line_mean  z_line_std  z_line_max  center_over_vol_mean  \
# 0                  1.000000          0.097333               0        1467.0  1296.535767  128.259003   1545.0  1425.800049   25.537424      1467.0              1.131477
# 1                  1.000000          0.265713               0        1264.0  1211.101196  173.248795   1554.0  1305.599976   61.444611      1413.0              1.043678
# 2                  3.605551          0.191140               0        1417.0  1204.424683  193.061600   1554.0  1280.400024  115.076675      1417.0              1.176495
# 3                  3.162278          0.090929               0        1435.0  1309.891357  223.779099   1805.0  1385.400024   98.347542      1470.0              1.095511
# 4                  2.000000          0.079901               0        1376.0  1320.669189  108.585258   1554.0  1373.199951   44.264656      1430.0              1.041896
#
#    center_minus_vol_mean  center_slice_minus_neighbor_mean  slice_mean_std  z_peak_offset  mass_center_offset_3d  peak_to_mean_ratio  bright_fraction  graph_neighbor_count  \
# 0             170.464233                        -15.080200       31.987671              1               0.109367            1.191637         0.607407                  16.0
# 1              52.898804                         -6.981445       46.583652              2               0.296657            1.283130         0.577778                  16.0
# 2             212.575317                         49.932129       96.423943              1               0.262051            1.290243         0.543210                  16.0
# 3             125.108643                         35.432129       99.626144              2               0.173655            1.377977         0.498765                  16.0
# 4              55.330811                         10.765381       41.015369              1               0.035532            1.176676         0.562963                  16.0
#
#    graph_mean_neighbor_distance  graph_min_neighbor_distance  graph_mean_neighbor_intensity  graph_mean_neighbor_contrast  graph_mean_neighbor_proposal_count   t  pred_dist  \
# 0                      5.879992                     2.187723                      1381.3750                    209.472061                              1.3125  60  10.388321
# 1                      5.297501                     2.071477                      1394.5000                    205.917587                              1.3750  60  10.841901
# 2                      5.298572                     2.071477                      1358.1875                    197.972061                              1.3750  60  11.274562
# 3                      6.099411                     2.368824                      1361.3750                    202.557251                              1.4375  60  12.356889
# 4                      5.330277                     2.187723                      1370.5625                    207.445053                              1.3750  60  12.429659
#
#    ranking_score  rank_position     detection_id
# 0     -10.388321              1  chapter34_t60_0
# 1     -10.841901              2  chapter34_t60_1
# 2     -11.274562              3  chapter34_t60_2
# 3     -12.356889              4  chapter34_t60_3
# 4     -12.429659              5  chapter34_t60_4
#     t  top_k  num_gt  num_pred  gt_detected  gt_missed  gt_recall  pred_matched  precision_like
# 0  60     25       9        25            1          8   0.111111             3          0.1200
# 1  60     50       9        50            3          6   0.333333             5          0.1000
# 2  60    100       9       100            4          5   0.444444            10          0.1000
# 3  60    200       9       200            6          3   0.666667            14          0.0700
# 4  60    400       9       400            7          2   0.777778            17          0.0425
# 5  80     25       6        25            2          4   0.333333             3          0.1200
# 6  80     50       6        50            2          4   0.333333             4          0.0800
# 7  80    100       6       100            3          3   0.500000             6          0.0600
# 8  80    200       6       200            3          3   0.500000             8          0.0400
# 9  80    400       6       400            4          2   0.666667             9          0.0225
#    top_k  mean_gt_recall  mean_precision_like  mean_num_pred
# 0     25        0.222222               0.1200           25.0
# 1     50        0.333333               0.0900           50.0
# 2    100        0.472222               0.0800          100.0
# 3    200        0.583333               0.0550          200.0
# 4    400        0.722222               0.0325          400.0
# t=0: raw=7795, nms=1768, ranked=1768, selected=200, time=6.5s
# t=1: raw=7532, nms=1773, ranked=1773, selected=200, time=6.6s
# t=2: raw=7886, nms=1799, ranked=1799, selected=200, time=6.8s
# t=3: raw=7641, nms=1798, ranked=1798, selected=200, time=6.6s
# t=4: raw=7838, nms=1851, ranked=1851, selected=200, time=6.7s
# t=5: raw=7421, nms=1754, ranked=1754, selected=200, time=6.7s
# t=6: raw=7261, nms=1735, ranked=1735, selected=200, time=6.6s
# t=7: raw=7317, nms=1729, ranked=1729, selected=200, time=6.5s
# t=8: raw=7696, nms=1823, ranked=1823, selected=200, time=6.6s
# t=9: raw=7892, nms=1854, ranked=1854, selected=200, time=6.9s
# t=10: raw=8014, nms=1862, ranked=1862, selected=200, time=6.7s
# t=11: raw=8196, nms=1941, ranked=1941, selected=200, time=6.8s
# t=12: raw=7927, nms=1881, ranked=1881, selected=200, time=6.7s
# t=13: raw=7853, nms=1879, ranked=1879, selected=200, time=7.0s
# t=14: raw=8018, nms=1859, ranked=1859, selected=200, time=6.7s
# t=15: raw=8052, nms=1890, ranked=1890, selected=200, time=6.7s
# t=16: raw=8023, nms=1871, ranked=1871, selected=200, time=6.7s
# t=17: raw=8129, nms=1945, ranked=1945, selected=200, time=7.0s
# t=18: raw=8147, nms=1925, ranked=1925, selected=200, time=6.8s
# t=19: raw=8058, nms=1900, ranked=1900, selected=200, time=6.7s
# t=20: raw=7968, nms=1859, ranked=1859, selected=200, time=6.9s
# t=21: raw=7720, nms=1835, ranked=1835, selected=200, time=6.7s
# t=22: raw=7503, nms=1778, ranked=1778, selected=200, time=6.7s
# t=23: raw=7675, nms=1831, ranked=1831, selected=200, time=6.7s
# t=24: raw=8055, nms=1890, ranked=1890, selected=200, time=6.9s
# t=25: raw=8183, nms=1915, ranked=1915, selected=200, time=6.7s
# t=26: raw=8136, nms=1899, ranked=1899, selected=200, time=6.8s
# t=27: raw=8142, nms=1914, ranked=1914, selected=200, time=7.0s
# t=28: raw=7860, nms=1874, ranked=1874, selected=200, time=6.8s
# t=29: raw=7808, nms=1894, ranked=1894, selected=200, time=6.7s
# t=30: raw=8101, nms=1928, ranked=1928, selected=200, time=6.8s
# t=31: raw=8233, nms=1951, ranked=1951, selected=200, time=7.1s
# t=32: raw=8147, nms=1942, ranked=1942, selected=200, time=6.9s
# t=33: raw=8324, nms=1962, ranked=1962, selected=200, time=6.8s
# t=34: raw=8248, nms=1958, ranked=1958, selected=200, time=6.9s
# t=35: raw=8562, nms=2032, ranked=2032, selected=200, time=6.9s
# t=36: raw=8489, nms=2006, ranked=2006, selected=200, time=7.0s
# t=37: raw=8486, nms=2032, ranked=2032, selected=200, time=7.1s
# t=38: raw=8288, nms=2001, ranked=2001, selected=200, time=7.0s
# t=39: raw=8203, nms=1964, ranked=1964, selected=200, time=6.9s
# t=40: raw=8022, nms=1941, ranked=1941, selected=200, time=6.7s
# t=41: raw=8444, nms=2005, ranked=2005, selected=200, time=7.0s
# t=42: raw=8675, nms=2100, ranked=2100, selected=200, time=7.0s
# t=43: raw=8744, nms=2082, ranked=2082, selected=200, time=7.1s
# t=44: raw=8647, nms=2059, ranked=2059, selected=200, time=6.9s
# t=45: raw=8795, nms=2133, ranked=2133, selected=200, time=7.2s
# t=46: raw=8729, nms=2117, ranked=2117, selected=200, time=7.1s
# t=47: raw=8833, nms=2112, ranked=2112, selected=200, time=7.0s
# t=48: raw=8845, nms=2136, ranked=2136, selected=200, time=7.3s
# t=49: raw=9160, nms=2207, ranked=2207, selected=200, time=7.2s
# t=50: raw=9039, nms=2155, ranked=2155, selected=200, time=7.2s
# t=51: raw=9160, nms=2201, ranked=2201, selected=200, time=7.3s
# t=52: raw=9061, nms=2156, ranked=2156, selected=200, time=7.1s
# t=53: raw=9055, nms=2183, ranked=2183, selected=200, time=7.1s
# t=54: raw=9018, nms=2179, ranked=2179, selected=200, time=7.3s
# t=55: raw=9220, nms=2232, ranked=2232, selected=200, time=7.1s
# t=56: raw=9245, nms=2234, ranked=2234, selected=200, time=7.2s
# t=57: raw=9142, nms=2198, ranked=2198, selected=200, time=7.3s
# t=58: raw=9397, nms=2269, ranked=2269, selected=200, time=7.3s
# t=59: raw=9282, nms=2218, ranked=2218, selected=200, time=7.2s
# t=60: raw=9146, nms=2221, ranked=2221, selected=200, time=7.3s
# t=61: raw=9187, nms=2222, ranked=2222, selected=200, time=7.2s
# t=62: raw=9181, nms=2223, ranked=2223, selected=200, time=7.3s
# t=63: raw=9276, nms=2254, ranked=2254, selected=200, time=7.4s
# t=64: raw=9476, nms=2294, ranked=2294, selected=200, time=7.4s
# t=65: raw=9068, nms=2234, ranked=2234, selected=200, time=7.2s
# t=66: raw=9522, nms=2301, ranked=2301, selected=200, time=7.4s
# t=67: raw=9269, nms=2290, ranked=2290, selected=200, time=7.3s
# t=68: raw=9278, nms=2266, ranked=2266, selected=200, time=7.3s
# t=69: raw=8916, nms=2202, ranked=2202, selected=200, time=7.2s
# t=70: raw=9556, nms=2328, ranked=2328, selected=200, time=7.3s
# t=71: raw=9655, nms=2398, ranked=2398, selected=200, time=7.5s
# t=72: raw=9958, nms=2431, ranked=2431, selected=200, time=7.5s
# t=73: raw=9747, nms=2366, ranked=2366, selected=200, time=7.3s
# t=74: raw=9774, nms=2370, ranked=2370, selected=200, time=7.5s
# t=75: raw=9939, nms=2413, ranked=2413, selected=200, time=7.4s
# t=76: raw=9890, nms=2394, ranked=2394, selected=200, time=7.3s
# t=77: raw=10179, nms=2485, ranked=2485, selected=200, time=7.7s
# t=78: raw=10008, nms=2456, ranked=2456, selected=200, time=7.5s
# t=79: raw=9931, nms=2444, ranked=2444, selected=200, time=7.5s
# t=80: raw=10040, nms=2460, ranked=2460, selected=200, time=7.7s
# t=81: raw=10173, nms=2479, ranked=2479, selected=200, time=7.5s
# t=82: raw=9777, nms=2411, ranked=2411, selected=200, time=7.5s
# t=83: raw=9553, nms=2360, ranked=2360, selected=200, time=7.3s
# t=84: raw=9631, nms=2379, ranked=2379, selected=200, time=7.3s
# t=85: raw=9593, nms=2339, ranked=2339, selected=200, time=7.5s
# t=86: raw=9576, nms=2377, ranked=2377, selected=200, time=7.3s
# t=87: raw=9764, nms=2467, ranked=2467, selected=200, time=7.5s
# t=88: raw=9720, nms=2461, ranked=2461, selected=200, time=7.7s
# t=89: raw=9733, nms=2416, ranked=2416, selected=200, time=7.4s
# t=90: raw=9435, nms=2348, ranked=2348, selected=200, time=7.3s
# t=91: raw=9545, nms=2366, ranked=2366, selected=200, time=7.5s
# t=92: raw=9587, nms=2432, ranked=2432, selected=200, time=7.3s
# t=93: raw=10027, nms=2494, ranked=2494, selected=200, time=7.6s
# t=94: raw=9970, nms=2480, ranked=2480, selected=200, time=7.6s
# t=95: raw=9790, nms=2444, ranked=2444, selected=200, time=7.5s
# t=96: raw=9650, nms=2412, ranked=2412, selected=200, time=7.6s
# t=97: raw=9727, nms=2420, ranked=2420, selected=200, time=7.7s
# t=98: raw=9726, nms=2414, ranked=2414, selected=200, time=7.4s
# t=99: raw=9800, nms=2454, ranked=2454, selected=200, time=7.5s
# Selected detections: 20000
# Full ranked candidates: 213224
#    t  raw_candidates  nms_candidates  ranked_candidates  selected_candidates  graph_edges  elapsed_seconds
# 0  0            7795            1768               1768                  200        24331         6.543468
# 1  1            7532            1773               1773                  200        24399         6.641781
# 2  2            7886            1799               1799                  200        24695         6.812452
# 3  3            7641            1798               1798                  200        24756         6.608400
# 4  4            7838            1851               1851                  200        25682         6.742348
#     z    y    x  sigma  proposal_count                                proposal_sources  proposal_peak_intensity  center_intensity   patch_mean  patch_max   patch_std  \
# 0  41  130  131    4.0               1                                   medium_strict                   1754.0            1754.0  1583.678955     1790.0  139.085632
# 1  24  123   85    4.0               3  large_sensitive|medium_sensitive|medium_strict                   1279.0            1279.0  1216.271606     1353.0   77.352806
# 2  37  193   95    5.0               1                                 large_sensitive                   1507.0            1507.0  1466.740723     1611.0   77.616463
# 3  17  255   95    5.0               1                                 large_sensitive                   1195.0            1195.0  1210.688843     1365.0   86.613266
# 4  25  125   88    3.5               1                                medium_sensitive                   1192.0            1192.0  1120.629639     1292.0   94.925629
#
#    local_contrast  center_to_patch_max_dist  patch_com_offset  is_near_border  center_voxel     vol_mean     vol_std  vol_max  z_line_mean  z_line_std  z_line_max  \
# 0      206.321045                  1.000000          0.053404               0        1754.0  1588.271606  268.745636   2273.0  1818.000000  286.623810      2226.0
# 1      136.728394                  1.414214          0.016496               0        1279.0  1073.913574  153.801559   1353.0  1160.599976   89.350098      1279.0
# 2      144.259277                  5.000000          0.085753               0        1507.0  1405.893799  155.466583   1770.0  1480.599976   92.300812      1627.0
# 3      154.311157                  2.000000          0.074207               1        1195.0  1058.982178  143.174789   1365.0  1064.800049  120.512901      1195.0
# 4      171.370361                  1.414214          0.112793               0        1192.0  1013.817261  169.832870   1353.0  1115.599976  101.653534      1243.0
#
#    center_over_vol_mean  center_minus_vol_mean  center_slice_minus_neighbor_mean  slice_mean_std  z_peak_offset  mass_center_offset_3d  peak_to_mean_ratio  bright_fraction  \
# 0              1.104345             165.728394                        -19.833374      179.018341              1               0.156987            1.431115         0.432099
# 1              1.190971             205.086426                         80.049438      114.613373              0               0.030025            1.259878         0.543210
# 2              1.071916             101.106201                         30.573975      122.085503              1               0.134474            1.258986         0.530864
# 3              1.128442             136.017822                         96.855469      116.555489              0               2.035556            1.288974         0.533333
# 4              1.175754             178.182739                         69.376587      109.624672              1               0.191783            1.334560         0.501235
#
#    graph_neighbor_count  graph_mean_neighbor_distance  graph_min_neighbor_distance  graph_mean_neighbor_intensity  graph_mean_neighbor_contrast  \
# 0                  16.0                      6.222860                     1.625000                      1660.5625                    294.091064
# 1                  16.0                      7.320772                     2.071477                      1383.4375                    293.540131
# 2                  16.0                      5.935493                     1.723573                      1556.0625                    249.272369
# 3                  16.0                      9.283495                     2.071477                      1226.3125                    199.058167
# 4                  16.0                      7.531094                     1.625000                      1371.1875                    286.811737
#
#    graph_mean_neighbor_proposal_count  t  pred_dist  ranking_score  rank_position    detection_id
# 0                              1.7500  0   7.354238      -7.354238              1  chapter34_t0_0
# 1                              1.4375  0   7.437489      -7.437489              2  chapter34_t0_1
# 2                              1.4375  0   7.584010      -7.584010              3  chapter34_t0_2
# 3                              1.5000  0   7.949785      -7.949785              4  chapter34_t0_3
# 4                              1.5625  0   8.260656      -8.260656              5  chapter34_t0_4
#    t  num_selected  within_top_k_limit  rank_positions_valid  unique_coordinates
# 0  0           200                True                  True                 200
# 1  1           200                True                  True                 200
# 2  2           200                True                  True                 200
# 3  3           200                True                  True                 200
# 4  4           200                True                  True                 200
# Output validation passed.
# Saved: /kaggle/working/chapter34_top200_detections.csv
# Saved: /kaggle/working/chapter34_full_ranked_candidates.csv
# Saved: /kaggle/working/chapter34_frame_summary.csv
# Saved: /kaggle/working/chapter34_validation_metrics.csv
# Saved: /kaggle/working/chapter34_training_candidates.csv
# Saved: /kaggle/working/chapter34_model_features.txt
# Checkpoints: /kaggle/working/chapter34_checkpoints
# Historical Chapter 34 pipeline function loaded.
# Signature: (raw_volume, ranking_model, feature_columns: 'list[str]', timepoints: 'Iterable[int]', config: 'DetectionConfig' = DetectionConfig(sample_id='44b6_12dfb391', nms_radius=3.0, oracle_radius=6.0, target_distance_clip=20.0, graph_radius_physical=12.0, max_graph_neighbors=16, patch_radius_2d=4, patch_radius_z=2, patch_radius_xy=4, top_k=200, train_timesteps=(0, 8, 20, 40), validation_timesteps=(60, 80), coordinate_scale_zyx=(1.625, 0.40625, 0.40625)), top_k: 'Optional[int]' = None, checkpoint_directory: 'Optional[Path | str]' = None)
# Detected ranking model: ranking_model
# Ranking model Python type: HistGradientBoostingRegressor
# Ranking model is class: False
# Feature schema source: model.feature_names_in_
# Resolved feature count: 32
# Resolved features: ['sigma', 'proposal_count', 'proposal_peak_intensity', 'center_intensity', 'patch_mean', 'patch_max', 'patch_std', 'local_contrast', 'center_to_patch_max_dist', 'patch_com_offset', 'is_near_border', 'center_voxel', 'vol_mean', 'vol_std', 'vol_max', 'z_line_mean', 'z_line_std', 'z_line_max', 'center_over_vol_mean', 'center_minus_vol_mean', 'center_slice_minus_neighbor_mean', 'slice_mean_std', 'z_peak_offset', 'mass_center_offset_3d', 'peak_to_mean_ratio', 'bright_fraction', 'graph_neighbor_count', 'graph_mean_neighbor_distance', 'graph_min_neighbor_distance', 'graph_mean_neighbor_intensity', 'graph_mean_neighbor_contrast', 'graph_mean_neighbor_proposal_count']
# Fallback historical feature variable: GRAPH_FEATURE_COLUMNS
# Fallback historical features: ['graph_neighbor_count', 'graph_mean_neighbor_distance', 'graph_min_neighbor_distance', 'graph_mean_neighbor_intensity', 'graph_mean_neighbor_contrast', 'graph_mean_neighbor_proposal_count']
# Estimator feature_names_in_: ['sigma', 'proposal_count', 'proposal_peak_intensity', 'center_intensity', 'patch_mean', 'patch_max', 'patch_std', 'local_contrast', 'center_to_patch_max_dist', 'patch_com_offset', 'is_near_border', 'center_voxel', 'vol_mean', 'vol_std', 'vol_max', 'z_line_mean', 'z_line_std', 'z_line_max', 'center_over_vol_mean', 'center_minus_vol_mean', 'center_slice_minus_neighbor_mean', 'slice_mean_std', 'z_peak_offset', 'mass_center_offset_3d', 'peak_to_mean_ratio', 'bright_fraction', 'graph_neighbor_count', 'graph_mean_neighbor_distance', 'graph_min_neighbor_distance', 'graph_mean_neighbor_intensity', 'graph_mean_neighbor_contrast', 'graph_mean_neighbor_proposal_count']
# ✓ Chapter 34 model/feature-schema preflight passed.

# %% [markdown]
# ## 6. Bootstrap Chapter 35–37 definitions and adapters
#
# Chapter 35 exposes `track_sequence(...)`. Chapters 36–37 are replayed by executing their historical algorithm sections after injecting the current sample's upstream DataFrames.
#
# No target-GT oracle/evaluation/training section is executed.

# %%
CH35_NAME = "chapter-35-motion-aware-tracking-with-gap-closin.ipynb"
CH36_NAME = "chapter-36-track-aware-detection-filtering.ipynb"
CH37_NAME = "chapter-37-track-refinement-and-gap-closing.ipynb"

ch35_nb = load_nb(SOURCE_PATHS[CH35_NAME])
ch36_nb = load_nb(SOURCE_PATHS[CH36_NAME])
ch37_nb = load_nb(SOURCE_PATHS[CH37_NAME])

CH35_DEFS = bootstrap_definition_cells(ch35_nb, "chapter35")
CH36_DEFS = bootstrap_definition_cells(ch36_nb, "chapter36")
CH37_DEFS = bootstrap_definition_cells(ch37_nb, "chapter37")

if "track_sequence" not in CH35_DEFS:
    recovered_functions = sorted(
        name
        for name, obj in CH35_DEFS.items()
        if callable(obj) and not name.startswith("_")
    )
    raise RuntimeError(
        "Could not recover historical Chapter 35 track_sequence(). "
        "This indicates a replay/bootstrap mismatch, not evidence that the "
        "historical notebook lacks the function. "
        f"Recovered callables: {recovered_functions}"
    )

print("Chapter 35 track_sequence recovered.")
print("Chapter 35 reusable signature:", inspect.signature(CH35_DEFS["track_sequence"]))
# Out:
# Chapter 35 track_sequence recovered.
# Chapter 35 reusable signature: (detections: 'pd.DataFrame', config: 'TrackingConfig' = TrackingConfig(sample_id='44b6_12dfb391', z_scale=1.625, y_scale=0.40625, x_scale=0.40625, max_link_distance=6.0, max_gap=2, rank_penalty_weight=0.35, pred_dist_penalty_weight=0.15, velocity_change_penalty_weight=0.25, node_match_radius=6.0))

# %%
def make_stage_config(ns, class_name: str, sample_id: str):
    cls = ns.get(class_name)
    if cls is None:
        return ns.get("CONFIG")

    try:
        return cls(sample_id=sample_id)
    except TypeError:
        base = ns.get("CONFIG")
        if base is not None:
            try:
                return replace(base, sample_id=sample_id)
            except Exception:
                return base
        return cls()


def _first_dataframe(mapping, keys):
    """Return the first DataFrame found under the supplied semantic keys."""
    if not isinstance(mapping, dict):
        return None, None

    for key in keys:
        value = mapping.get(key)
        if isinstance(value, pd.DataFrame):
            return key, value.copy()

    return None, None


def _adapt_tracking_result(result, stage_name: str):
    """
    Orchestration-only adapter for historical tracking return shapes.

    The Chapter 35 historical tracker returns a dict containing:
      - track_nodes
      - track_edges
      - frame_summary

    Tuple support is retained for compatibility with older recovered variants.
    No tracking decisions are changed here.
    """
    if isinstance(result, dict):
        print(
            f"{stage_name} adapter: received dict with keys:",
            sorted(map(str, result.keys())),
        )

        node_key, nodes = _first_dataframe(
            result,
            (
                "track_nodes",
                "track_nodes_df",
                "filtered_track_nodes",
                "filtered_track_nodes_df",
                "refined_track_nodes",
                "refined_track_nodes_df",
            ),
        )
        edge_key, edges = _first_dataframe(
            result,
            (
                "track_edges",
                "track_edges_df",
                "filtered_track_edges",
                "filtered_track_edges_df",
                "refined_track_edges",
                "refined_track_edges_df",
            ),
        )
        frame_key, frame_summary = _first_dataframe(
            result,
            (
                "frame_summary",
                "frame_summary_df",
                "tracking_frame_summary",
            ),
        )

        if nodes is not None and edges is not None:
            print(
                f"{stage_name} adapter: nodes={node_key!r}, "
                f"edges={edge_key!r}, frame_summary={frame_key!r}"
            )
            if frame_summary is None:
                frame_summary = pd.DataFrame()
            return nodes, edges, frame_summary

        raise RuntimeError(
            f"{stage_name} returned a dict, but track nodes/edges could "
            f"not be resolved. Keys: {sorted(map(str, result.keys()))}"
        )

    if isinstance(result, tuple):
        frames = [x for x in result if isinstance(x, pd.DataFrame)]
        if len(frames) >= 2:
            print(
                f"{stage_name} adapter: received tuple with "
                f"{len(frames)} DataFrame value(s)"
            )
            frame_summary = frames[2].copy() if len(frames) >= 3 else pd.DataFrame()
            return frames[0].copy(), frames[1].copy(), frame_summary

        raise RuntimeError(
            f"{stage_name} returned a tuple without at least two DataFrames."
        )

    raise RuntimeError(
        f"{stage_name} returned an unexpected result type: {type(result)!r}"
    )


def _summarize_tracks_compat(ns, nodes: pd.DataFrame, edges: pd.DataFrame):
    summary_fn = (
        ns.get("summarize_tracks")
        or ns.get("build_track_summary")
        or ns.get("track_summary")
    )

    if callable(summary_fn):
        try:
            return summary_fn(nodes, edges)
        except TypeError:
            return summary_fn(nodes)

    # Orchestration-only fallback summary. Tracking decisions are unchanged.
    agg = {
        "start_t": ("t", "min"),
        "end_t": ("t", "max"),
        "num_detections": ("t", "size"),
    }
    if "rank_position" in nodes.columns:
        agg["mean_rank"] = ("rank_position", "mean")
    if "pred_dist" in nodes.columns:
        agg["mean_pred_dist"] = ("pred_dist", "mean")

    return nodes.groupby("track_id", as_index=False).agg(**agg)


def run_ch35(detections_df: pd.DataFrame, sample_id: str):
    ns = dict(CH35_DEFS)
    config = make_stage_config(ns, "TrackingConfig", sample_id)

    det = detections_df.copy()

    # Historical Ch35 physical-coordinate convention.
    for axis, attr in (
        ("z", "z_scale"),
        ("y", "y_scale"),
        ("x", "x_scale"),
    ):
        physical = f"{axis}_physical"
        if physical not in det.columns:
            det[physical] = (
                det[axis].astype(float)
                * float(getattr(config, attr))
            )

    result = ns["track_sequence"](det, config=config)
    nodes, edges, _frame_summary = _adapt_tracking_result(
        result,
        "Ch35",
    )

    summary = _summarize_tracks_compat(ns, nodes, edges)

    return nodes, edges, summary


def run_ch36(
    detections_df: pd.DataFrame,
    ch35_nodes: pd.DataFrame,
    ch35_edges: pd.DataFrame,
    ch35_summary: pd.DataFrame,
    sample_id: str,
):
    ns = dict(CH36_DEFS)
    ns.update(
        {
            "detections_df": detections_df.copy(),
            "track_nodes_df": ch35_nodes.copy(),
            "track_edges_df": ch35_edges.copy(),
            "track_summary_df": ch35_summary.copy(),
        }
    )

    ns["CONFIG"] = make_stage_config(
        ns, "FilteringConfig", sample_id
    )

    # Exact historical feature + label-free support sections.
    run_heading_sections(
        ch36_nb,
        ns,
        include_patterns=[
            r"Step 2\b",
            r"Step 3\b",
            r"Step 4\b",
            r"Step 5\b",
            r"Step 6\b",
        ],
    )

    if "feature_df" not in ns:
        raise RuntimeError(
            "Chapter 36 replay did not produce feature_df."
        )

    feature_df = ns["feature_df"].copy()

    # Frozen-model only. Never fit on a new target sample.
    frozen_model = CH36_DEFS.get("FROZEN_TEMPORAL_MODEL")
    model_features = CH36_DEFS.get("MODEL_FEATURE_COLUMNS")

    if frozen_model is not None and model_features is not None:
        x = feature_df[list(model_features)].fillna(0.0)
        feature_df["temporal_model_probability"] = (
            frozen_model.predict_proba(x)[:, 1]
        )
        feature_df["final_filter_score"] = (
            0.60 * feature_df["temporal_model_probability"]
            + 0.40 * feature_df["temporal_support_score"]
        )
        filter_mode = "frozen_historical_temporal_model"
    else:
        feature_df["temporal_model_probability"] = np.nan
        feature_df["final_filter_score"] = (
            feature_df["temporal_support_score"]
        )
        filter_mode = "historical_label_free_temporal_support"

    ns["feature_df"] = feature_df

    # Exact historical selection and filtered graph construction.
    run_heading_sections(
        ch36_nb,
        ns,
        include_patterns=[
            r"Step 10\b",
            r"Step 11\b",
        ],
    )

    # Prefer the historical namespace variables exactly as saved.
    filtered = ns.get("filtered_detections_df")
    nodes = ns.get("filtered_track_nodes_df")
    edges = ns.get("filtered_track_edges_df")

    # Defensive support for recovered variants that expose a result mapping.
    for result_name in (
        "filtering_results",
        "filtered_results",
        "tracking_results",
        "results",
    ):
        result = ns.get(result_name)
        if not isinstance(result, dict):
            continue

        if filtered is None:
            _, filtered_candidate = _first_dataframe(
                result,
                (
                    "filtered_detections",
                    "filtered_detections_df",
                    "detections",
                    "selected_detections",
                ),
            )
            if filtered_candidate is not None:
                filtered = filtered_candidate

        if nodes is None or edges is None:
            try:
                adapted_nodes, adapted_edges, _ = _adapt_tracking_result(
                    result,
                    "Ch36",
                )
                if nodes is None:
                    nodes = adapted_nodes
                if edges is None:
                    edges = adapted_edges
            except RuntimeError:
                pass

    if filtered is None:
        raise RuntimeError(
            "Chapter 36 replay did not produce filtered_detections_df."
        )

    # If a recovered Ch36 variant omitted its retracked node/edge variables,
    # rebuild them with the unchanged historical Chapter 35 tracker.
    if nodes is None or edges is None:
        ch35_ns = dict(CH35_DEFS)
        config = make_stage_config(
            ch35_ns,
            "TrackingConfig",
            sample_id,
        )

        filtered_for_tracking = filtered.copy()
        for axis, attr in (
            ("z", "z_scale"),
            ("y", "y_scale"),
            ("x", "x_scale"),
        ):
            physical = f"{axis}_physical"
            if physical not in filtered_for_tracking.columns:
                filtered_for_tracking[physical] = (
                    filtered_for_tracking[axis].astype(float)
                    * float(getattr(config, attr))
                )

        retracked = ch35_ns["track_sequence"](
            filtered_for_tracking,
            config=config,
        )
        nodes, edges, _ = _adapt_tracking_result(
            retracked,
            "Ch36 retracking",
        )

    return filtered.copy(), nodes.copy(), edges.copy(), filter_mode


def run_ch37(
    ch36_filtered: pd.DataFrame,
    ch36_nodes: pd.DataFrame,
    ch36_edges: pd.DataFrame,
    sample_id: str,
):
    ns = dict(CH37_DEFS)
    ns.update(
        {
            "filtered_detections_df": ch36_filtered.copy(),
            "filtered_track_nodes_df": ch36_nodes.copy(),
            "filtered_track_edges_df": ch36_edges.copy(),
            "detections_df": ch36_filtered.copy(),
            "track_nodes_df": ch36_nodes.copy(),
            "track_edges_df": ch36_edges.copy(),
        }
    )

    ns["CONFIG"] = make_stage_config(
        ns, "RefinementConfig", sample_id
    )

    run_heading_sections(
        ch37_nb,
        ns,
        include_patterns=[r"## Step"],
        skip_patterns=[
            r"(locate|load).*chapter 36",
            r"ground truth",
            r"\bGT\b",
            r"evaluat",
            r"validat",
            r"plot",
            r"visual",
            r"save",
        ],
    )

    nodes = (
        ns.get("refined_track_nodes_df")
        if ns.get("refined_track_nodes_df") is not None
        else ns.get("refined_nodes_df")
    )
    edges = (
        ns.get("refined_track_edges_df")
        if ns.get("refined_track_edges_df") is not None
        else ns.get("refined_edges_df")
    )
    summary = (
        ns.get("refined_track_summary_df")
        if ns.get("refined_track_summary_df") is not None
        else ns.get("track_summary_df")
    )

    # Defensive support for recovered Chapter 37 variants that package
    # refined outputs into a dict instead of namespace variables.
    for result_name in (
        "refinement_results",
        "refined_results",
        "results",
    ):
        result = ns.get(result_name)
        if not isinstance(result, dict):
            continue

        if nodes is None:
            _, value = _first_dataframe(
                result,
                (
                    "refined_track_nodes",
                    "refined_track_nodes_df",
                    "track_nodes",
                ),
            )
            if value is not None:
                nodes = value

        if edges is None:
            _, value = _first_dataframe(
                result,
                (
                    "refined_track_edges",
                    "refined_track_edges_df",
                    "track_edges",
                ),
            )
            if value is not None:
                edges = value

        if summary is None:
            _, value = _first_dataframe(
                result,
                (
                    "refined_track_summary",
                    "refined_track_summary_df",
                    "track_summary",
                ),
            )
            if value is not None:
                summary = value

    if nodes is None or edges is None:
        raise RuntimeError(
            "Chapter 37 replay did not expose refined nodes/edges. "
            "Update only this adapter if historical variable names changed."
        )

    if summary is None:
        summary = _summarize_tracks_compat(
            dict(CH35_DEFS),
            nodes,
            edges,
        )

    return nodes.copy(), edges.copy(), summary.copy()

# %% [markdown]
# ## 7. Run the frozen pipeline per selected sample
#
# Each sample is processed independently. Any stage exception is recorded in `chapter46a_failures.csv`; the sample is not silently omitted.

# %%
FAILURES = []
VALIDATION = []
SAMPLE_SUMMARY = []

CH34_ALL = []
CH35_NODES_ALL = []
CH35_EDGES_ALL = []
CH35_SUMMARY_ALL = []
CH36_DET_ALL = []
CH36_NODES_ALL = []
CH36_EDGES_ALL = []
CH37_NODES_ALL = []
CH37_EDGES_ALL = []
CH37_SUMMARY_ALL = []


def flush_failures():
    pd.DataFrame(FAILURES).to_csv(
        CONFIG.output_dir / "chapter46a_failures.csv",
        index=False,
    )


def record_failure(sample_id: str, stage: str, exc: Exception):
    FAILURES.append(
        {
            "sample_id": sample_id,
            "stage": stage,
            "error_type": type(exc).__name__,
            "message": str(exc),
            "traceback": traceback.format_exc(),
        }
    )
    flush_failures()


def strip_qualifiers(df: pd.DataFrame) -> pd.DataFrame:
    drop = [
        c
        for c in df.columns
        if c == "sample_id" or c.startswith("global_")
    ]
    return df.drop(columns=drop, errors="ignore").copy()


def checkpoint_paths(sample_dir: Path, stage: str):
    mapping = {
        "ch34": [
            sample_dir / "chapter34_top200_detections.csv",
        ],
        "ch35": [
            sample_dir / "chapter35_track_nodes.csv",
            sample_dir / "chapter35_track_edges.csv",
            sample_dir / "chapter35_track_summary.csv",
        ],
        "ch36": [
            sample_dir / "chapter36_filtered_detections.csv",
            sample_dir / "chapter36_filtered_track_nodes.csv",
            sample_dir / "chapter36_filtered_track_edges.csv",
        ],
        "ch37": [
            sample_dir / "chapter37_refined_track_nodes.csv",
            sample_dir / "chapter37_refined_track_edges.csv",
            sample_dir / "chapter37_refined_track_summary.csv",
        ],
    }
    return mapping[stage]


def checkpoint_ready(sample_dir: Path, stage: str) -> bool:
    return (
        CONFIG.reuse_stage_checkpoints
        and all(path.exists() for path in checkpoint_paths(sample_dir, stage))
    )


def read_checkpoint(sample_dir: Path, stage: str):
    paths = checkpoint_paths(sample_dir, stage)
    frames = [pd.read_csv(path) for path in paths]
    print(
        f"{stage.upper()} checkpoint: reused "
        + ", ".join(f"{p.name} ({len(df):,} rows)" for p, df in zip(paths, frames))
    )
    return frames


def adapt_ch34_result(result):
    """V10/V11 Chapter 34 return-shape adapter, unchanged algorithmically."""
    if isinstance(result, pd.DataFrame):
        ch34_df = result.copy()
        print("Ch34 adapter: received DataFrame directly")

    elif isinstance(result, tuple):
        frames = [x for x in result if isinstance(x, pd.DataFrame)]
        if not frames:
            raise RuntimeError("Chapter 34 returned no DataFrame.")
        ch34_df = max(frames, key=len).copy()
        print("Ch34 adapter: using largest DataFrame from tuple", ch34_df.shape)

    elif isinstance(result, dict):
        print(
            "Ch34 adapter: received dict with keys:",
            sorted(map(str, result.keys())),
        )

        preferred_keys = (
            "selected_detections",
            "detections",
            "ranked_detections",
            "top_detections",
            "top200_detections",
            "results",
            "dataframe",
            "df",
        )

        ch34_df = None

        for key in preferred_keys:
            value = result.get(key)
            if isinstance(value, pd.DataFrame):
                ch34_df = value.copy()
                print(f"Ch34 adapter: using DataFrame from result[{key!r}]")
                break

        if ch34_df is None:
            dataframe_items = [
                (key, value)
                for key, value in result.items()
                if isinstance(value, pd.DataFrame)
            ]

            if len(dataframe_items) == 1:
                key, value = dataframe_items[0]
                ch34_df = value.copy()
                print(f"Ch34 adapter: using sole DataFrame from result[{key!r}]")

            elif len(dataframe_items) > 1:
                detection_like = []

                for key, value in dataframe_items:
                    cols = {str(c).lower() for c in value.columns}
                    has_time = bool({"t", "time", "timepoint"} & cols)
                    has_coords = (
                        {"z", "y", "x"}.issubset(cols)
                        or {"z_px", "y_px", "x_px"}.issubset(cols)
                    )

                    if has_time and has_coords:
                        detection_like.append((key, value))

                if len(detection_like) == 1:
                    key, value = detection_like[0]
                    ch34_df = value.copy()
                    print(
                        "Ch34 adapter: using detection-like "
                        f"DataFrame from result[{key!r}]"
                    )
                else:
                    detail = {
                        str(key): {
                            "shape": tuple(value.shape),
                            "columns": [str(c) for c in value.columns[:20]],
                        }
                        for key, value in dataframe_items
                    }
                    raise RuntimeError(
                        "Chapter 34 returned multiple DataFrames and the adapter "
                        "could not uniquely identify detections. "
                        f"Candidates: {detail}"
                    )
            else:
                raise RuntimeError(
                    "Chapter 34 returned a dict but no DataFrame value was found. "
                    f"Keys: {sorted(map(str, result.keys()))}"
                )

    else:
        raise RuntimeError(
            f"Unexpected Chapter 34 result type: {type(result)}"
        )

    if "rank_position" not in ch34_df.columns:
        raise RuntimeError("Chapter 34 output lacks rank_position.")

    # Preserve the historical top-200-per-timepoint contract.
    ch34_df = (
        ch34_df.sort_values(["t", "rank_position"])
        .groupby("t", group_keys=False)
        .head(200)
        .reset_index(drop=True)
    )

    return ch34_df


for _, selected in selected_samples.iterrows():
    sample_id = str(selected["sample_id"])
    gt_binary_divisions = int(selected["gt_binary_divisions"])
    sample_dir = CONFIG.per_sample_dir / sample_id
    sample_dir.mkdir(parents=True, exist_ok=True)

    status = {
        "sample_id": sample_id,
        "gt_binary_divisions": gt_binary_divisions,
        "ch34_ok": False,
        "ch35_ok": False,
        "ch36_ok": False,
        "ch37_ok": False,
        "filter_mode": "",
        "final_status": "FAILED",
    }

    ch34_rows = np.nan
    ch36_rows = np.nan
    ch37_nodes_n = np.nan
    ch37_tracks_n = np.nan

    print("\n" + "=" * 90)
    print(
        "SAMPLE:", sample_id,
        "| GT binary divisions:", gt_binary_divisions,
    )

    # ---------------- Chapter 34 ----------------
    try:
        if checkpoint_ready(sample_dir, "ch34"):
            (ch34_df,) = read_checkpoint(sample_dir, "ch34")
        else:
            result = run_ch34_for_sample(sample_id)
            ch34_df = adapt_ch34_result(result)

            if "sample_id" not in ch34_df.columns:
                ch34_df.insert(0, "sample_id", sample_id)

            ch34_df.to_csv(
                sample_dir / "chapter34_top200_detections.csv",
                index=False,
            )

        if "sample_id" not in ch34_df.columns:
            ch34_df.insert(0, "sample_id", sample_id)

        CH34_ALL.append(ch34_df)
        ch34_rows = len(ch34_df)
        status["ch34_ok"] = True
        print("Ch34:", ch34_rows, "rows")

    except Exception as exc:
        record_failure(sample_id, "chapter34", exc)
        print("FAILED Ch34:", exc)
        VALIDATION.append(status)
        SAMPLE_SUMMARY.append(
            {
                "sample_id": sample_id,
                "gt_binary_divisions": gt_binary_divisions,
                "ch34_rows": ch34_rows,
                "ch36_rows": ch36_rows,
                "ch37_nodes": ch37_nodes_n,
                "ch37_track_count": ch37_tracks_n,
            }
        )
        continue

    # ---------------- Chapter 35 ----------------
    try:
        if checkpoint_ready(sample_dir, "ch35"):
            ch35_nodes, ch35_edges, ch35_summary = read_checkpoint(
                sample_dir, "ch35"
            )
        else:
            ch35_nodes, ch35_edges, ch35_summary = run_ch35(
                strip_qualifiers(ch34_df),
                sample_id,
            )

            ch35_nodes = qualify_track_ids(ch35_nodes, sample_id)
            ch35_edges = qualify_track_ids(ch35_edges, sample_id)
            ch35_summary = qualify_track_ids(ch35_summary, sample_id)

            ch35_nodes.to_csv(
                sample_dir / "chapter35_track_nodes.csv",
                index=False,
            )
            ch35_edges.to_csv(
                sample_dir / "chapter35_track_edges.csv",
                index=False,
            )
            ch35_summary.to_csv(
                sample_dir / "chapter35_track_summary.csv",
                index=False,
            )

        CH35_NODES_ALL.append(ch35_nodes)
        CH35_EDGES_ALL.append(ch35_edges)
        CH35_SUMMARY_ALL.append(ch35_summary)

        status["ch35_ok"] = True
        print(
            "Ch35:",
            len(ch35_nodes), "nodes,",
            len(ch35_edges), "edges,",
            ch35_nodes["track_id"].nunique()
            if "track_id" in ch35_nodes.columns
            else "n/a",
            "tracks",
        )

    except Exception as exc:
        record_failure(sample_id, "chapter35", exc)
        print("FAILED Ch35:", exc)
        VALIDATION.append(status)
        SAMPLE_SUMMARY.append(
            {
                "sample_id": sample_id,
                "gt_binary_divisions": gt_binary_divisions,
                "ch34_rows": ch34_rows,
                "ch36_rows": ch36_rows,
                "ch37_nodes": ch37_nodes_n,
                "ch37_track_count": ch37_tracks_n,
            }
        )
        continue

    # ---------------- Chapter 36 ----------------
    try:
        if checkpoint_ready(sample_dir, "ch36"):
            ch36_filtered, ch36_nodes, ch36_edges = read_checkpoint(
                sample_dir, "ch36"
            )
            filter_mode = "checkpoint_reuse"
        else:
            (
                ch36_filtered,
                ch36_nodes,
                ch36_edges,
                filter_mode,
            ) = run_ch36(
                strip_qualifiers(ch34_df),
                strip_qualifiers(ch35_nodes),
                strip_qualifiers(ch35_edges),
                strip_qualifiers(ch35_summary),
                sample_id,
            )

            ch36_filtered = qualify_track_ids(ch36_filtered, sample_id)
            ch36_nodes = qualify_track_ids(ch36_nodes, sample_id)
            ch36_edges = qualify_track_ids(ch36_edges, sample_id)

            ch36_filtered.to_csv(
                sample_dir / "chapter36_filtered_detections.csv",
                index=False,
            )
            ch36_nodes.to_csv(
                sample_dir / "chapter36_filtered_track_nodes.csv",
                index=False,
            )
            ch36_edges.to_csv(
                sample_dir / "chapter36_filtered_track_edges.csv",
                index=False,
            )

        CH36_DET_ALL.append(ch36_filtered)
        CH36_NODES_ALL.append(ch36_nodes)
        CH36_EDGES_ALL.append(ch36_edges)

        ch36_rows = len(ch36_filtered)
        status["ch36_ok"] = True
        status["filter_mode"] = filter_mode
        print("Ch36:", ch36_rows, "rows |", filter_mode)

    except Exception as exc:
        record_failure(sample_id, "chapter36", exc)
        print("FAILED Ch36:", exc)
        VALIDATION.append(status)
        SAMPLE_SUMMARY.append(
            {
                "sample_id": sample_id,
                "gt_binary_divisions": gt_binary_divisions,
                "ch34_rows": ch34_rows,
                "ch36_rows": ch36_rows,
                "ch37_nodes": ch37_nodes_n,
                "ch37_track_count": ch37_tracks_n,
            }
        )
        continue

    # ---------------- Chapter 37 ----------------
    try:
        if checkpoint_ready(sample_dir, "ch37"):
            ch37_nodes, ch37_edges, ch37_summary = read_checkpoint(
                sample_dir, "ch37"
            )
        else:
            ch37_nodes, ch37_edges, ch37_summary = run_ch37(
                strip_qualifiers(ch36_filtered),
                strip_qualifiers(ch36_nodes),
                strip_qualifiers(ch36_edges),
                sample_id,
            )

            ch37_nodes = qualify_track_ids(ch37_nodes, sample_id)
            ch37_edges = qualify_track_ids(ch37_edges, sample_id)
            ch37_summary = qualify_track_ids(ch37_summary, sample_id)

            ch37_nodes.to_csv(
                sample_dir / "chapter37_refined_track_nodes.csv",
                index=False,
            )
            ch37_edges.to_csv(
                sample_dir / "chapter37_refined_track_edges.csv",
                index=False,
            )
            ch37_summary.to_csv(
                sample_dir / "chapter37_refined_track_summary.csv",
                index=False,
            )

        CH37_NODES_ALL.append(ch37_nodes)
        CH37_EDGES_ALL.append(ch37_edges)
        CH37_SUMMARY_ALL.append(ch37_summary)

        ch37_nodes_n = len(ch37_nodes)
        ch37_tracks_n = (
            ch37_nodes["track_id"].nunique()
            if "track_id" in ch37_nodes.columns
            else np.nan
        )

        status["ch37_ok"] = True
        status["final_status"] = "COMPLETE"

        print(
            "Ch37:",
            ch37_nodes_n, "nodes,",
            ch37_tracks_n, "tracks",
        )

    except Exception as exc:
        record_failure(sample_id, "chapter37", exc)
        print("FAILED Ch37:", exc)

    VALIDATION.append(status)
    SAMPLE_SUMMARY.append(
        {
            "sample_id": sample_id,
            "gt_binary_divisions": gt_binary_divisions,
            "ch34_rows": ch34_rows,
            "ch36_rows": ch36_rows,
            "ch37_nodes": ch37_nodes_n,
            "ch37_track_count": ch37_tracks_n,
        }
    )

flush_failures()
# Out:
# ==========================================================================================
# SAMPLE: 6bba_48816121 | GT binary divisions: 5
# Ch34 sample: 6bba_48816121
#   zarr: /kaggle/input/competitions/biohub-cell-tracking-during-development/train/6bba_48816121.zarr
#   raw volume shape: (100, 64, 256, 256)
#   timepoints: 100
#   config sample_id: 6bba_48816121
# t=0: raw=4723, nms=1030, ranked=1030, selected=200, time=5.8s
# t=1: raw=4951, nms=1086, ranked=1086, selected=200, time=5.8s
# t=2: raw=4897, nms=1081, ranked=1081, selected=200, time=5.8s
# t=3: raw=4874, nms=1080, ranked=1080, selected=200, time=5.8s
# t=4: raw=5042, nms=1115, ranked=1115, selected=200, time=5.9s
# t=5: raw=5194, nms=1146, ranked=1146, selected=200, time=6.0s
# t=6: raw=5192, nms=1147, ranked=1147, selected=200, time=5.9s
# t=7: raw=4993, nms=1099, ranked=1099, selected=200, time=5.9s
# t=8: raw=5264, nms=1187, ranked=1187, selected=200, time=6.0s
# t=9: raw=5278, nms=1155, ranked=1155, selected=200, time=5.9s
# t=10: raw=5161, nms=1117, ranked=1117, selected=200, time=5.9s
# t=11: raw=5131, nms=1083, ranked=1083, selected=200, time=6.0s
# t=12: raw=5385, nms=1138, ranked=1138, selected=200, time=5.8s
# t=13: raw=5317, nms=1157, ranked=1157, selected=200, time=5.9s
# t=14: raw=5208, nms=1110, ranked=1110, selected=200, time=5.9s
# t=15: raw=5371, nms=1140, ranked=1140, selected=200, time=6.0s
# t=16: raw=5260, nms=1153, ranked=1153, selected=200, time=5.9s
# t=17: raw=5297, nms=1122, ranked=1122, selected=200, time=6.2s
# t=18: raw=5121, nms=1125, ranked=1125, selected=200, time=5.9s
# t=19: raw=4908, nms=1061, ranked=1061, selected=200, time=5.8s
# t=20: raw=5128, nms=1113, ranked=1113, selected=200, time=5.9s
# t=21: raw=5079, nms=1093, ranked=1093, selected=200, time=5.8s
# t=22: raw=4959, nms=1091, ranked=1091, selected=200, time=5.9s
# t=23: raw=4869, nms=1099, ranked=1099, selected=200, time=5.9s
# t=24: raw=4978, nms=1083, ranked=1083, selected=200, time=5.9s
# t=25: raw=4969, nms=1085, ranked=1085, selected=200, time=5.8s
# t=26: raw=4844, nms=1067, ranked=1067, selected=200, time=5.8s
# t=27: raw=5037, nms=1103, ranked=1103, selected=200, time=5.8s
# t=28: raw=4887, nms=1081, ranked=1081, selected=200, time=5.8s
# t=29: raw=4895, nms=1065, ranked=1065, selected=200, time=5.8s
# t=30: raw=4915, nms=1042, ranked=1042, selected=200, time=5.8s
# t=31: raw=5090, nms=1132, ranked=1132, selected=200, time=6.0s
# t=32: raw=4703, nms=1043, ranked=1043, selected=200, time=5.7s
# t=33: raw=4645, nms=991, ranked=991, selected=200, time=5.7s
# t=34: raw=4819, nms=1047, ranked=1047, selected=200, time=5.8s
# t=35: raw=4859, nms=1052, ranked=1052, selected=200, time=5.8s
# t=36: raw=4880, nms=1058, ranked=1058, selected=200, time=5.8s
# t=37: raw=4561, nms=1005, ranked=1005, selected=200, time=5.9s
# t=38: raw=4640, nms=1000, ranked=1000, selected=200, time=5.7s
# t=39: raw=4713, nms=1007, ranked=1007, selected=200, time=5.7s
# t=40: raw=4603, nms=1012, ranked=1012, selected=200, time=5.8s
# t=41: raw=4838, nms=1049, ranked=1049, selected=200, time=5.8s
# t=42: raw=4401, nms=961, ranked=961, selected=200, time=5.6s
# t=43: raw=4618, nms=1013, ranked=1013, selected=200, time=5.8s
# t=44: raw=4367, nms=972, ranked=972, selected=200, time=5.6s
# t=45: raw=4474, nms=992, ranked=992, selected=200, time=5.9s
# t=46: raw=4325, nms=956, ranked=956, selected=200, time=5.7s
# t=47: raw=4195, nms=930, ranked=930, selected=200, time=5.7s
# t=48: raw=4478, nms=998, ranked=998, selected=200, time=5.8s
# t=49: raw=4316, nms=979, ranked=979, selected=200, time=5.8s
# t=50: raw=4274, nms=922, ranked=922, selected=200, time=5.6s
# t=51: raw=4244, nms=917, ranked=917, selected=200, time=5.6s
# t=52: raw=4437, nms=940, ranked=940, selected=200, time=5.7s
# t=53: raw=4559, nms=953, ranked=953, selected=200, time=5.8s
# t=54: raw=4654, nms=993, ranked=993, selected=200, time=5.7s
# t=55: raw=4365, nms=942, ranked=942, selected=200, time=5.7s
# t=56: raw=4699, nms=1034, ranked=1034, selected=200, time=5.8s
# t=57: raw=4526, nms=973, ranked=973, selected=200, time=5.7s
# t=58: raw=4641, nms=999, ranked=999, selected=200, time=5.6s
# t=59: raw=4371, nms=968, ranked=968, selected=200, time=5.7s
# t=60: raw=4599, nms=981, ranked=981, selected=200, time=5.9s
# t=61: raw=4501, nms=956, ranked=956, selected=200, time=5.6s
# t=62: raw=4408, nms=929, ranked=929, selected=200, time=5.6s
# t=63: raw=4700, nms=980, ranked=980, selected=200, time=5.7s
# t=64: raw=4562, nms=975, ranked=975, selected=200, time=5.6s
# t=65: raw=4430, nms=960, ranked=960, selected=200, time=5.7s
# t=66: raw=4279, nms=908, ranked=908, selected=200, time=5.6s
# t=67: raw=4378, nms=927, ranked=927, selected=200, time=5.7s
# t=68: raw=4286, nms=929, ranked=929, selected=200, time=5.8s
# t=69: raw=4393, nms=966, ranked=966, selected=200, time=5.7s
# t=70: raw=4346, nms=903, ranked=903, selected=200, time=5.6s
# t=71: raw=4350, nms=912, ranked=912, selected=200, time=5.6s
# t=72: raw=4476, nms=935, ranked=935, selected=200, time=5.7s
# t=73: raw=4203, nms=917, ranked=917, selected=200, time=5.6s
# t=74: raw=4471, nms=950, ranked=950, selected=200, time=5.6s
# t=75: raw=4461, nms=949, ranked=949, selected=200, time=5.6s
# t=76: raw=4341, nms=942, ranked=942, selected=200, time=5.8s
# t=77: raw=4305, nms=927, ranked=927, selected=200, time=5.6s
# t=78: raw=4364, nms=945, ranked=945, selected=200, time=5.6s
# t=79: raw=4301, nms=940, ranked=940, selected=200, time=5.6s
# t=80: raw=4201, nms=887, ranked=887, selected=200, time=5.5s
# t=81: raw=4319, nms=922, ranked=922, selected=200, time=5.6s
# t=82: raw=4180, nms=905, ranked=905, selected=200, time=5.6s
# t=83: raw=4371, nms=925, ranked=925, selected=200, time=5.7s
# t=84: raw=4439, nms=938, ranked=938, selected=200, time=5.6s
# t=85: raw=4224, nms=903, ranked=903, selected=200, time=5.7s
# t=86: raw=4259, nms=905, ranked=905, selected=200, time=5.5s
# t=87: raw=4254, nms=901, ranked=901, selected=200, time=5.6s
# t=88: raw=4361, nms=915, ranked=915, selected=200, time=5.6s
# t=89: raw=4510, nms=958, ranked=958, selected=200, time=5.6s
# t=90: raw=4437, nms=930, ranked=930, selected=200, time=5.6s
# t=91: raw=4184, nms=887, ranked=887, selected=200, time=5.6s
# t=92: raw=4222, nms=919, ranked=919, selected=200, time=5.7s
# t=93: raw=4411, nms=937, ranked=937, selected=200, time=5.6s
# t=94: raw=4159, nms=884, ranked=884, selected=200, time=5.7s
# t=95: raw=4303, nms=931, ranked=931, selected=200, time=5.6s
# t=96: raw=4146, nms=884, ranked=884, selected=200, time=5.6s
# t=97: raw=4071, nms=887, ranked=887, selected=200, time=5.6s
# t=98: raw=4151, nms=871, ranked=871, selected=200, time=5.5s
# t=99: raw=4038, nms=870, ranked=870, selected=200, time=5.6s
# Ch34 adapter: received dict with keys: ['frame_summary', 'full_ranked_candidates', 'selected_detections']
# Ch34 adapter: using DataFrame from result['selected_detections']
# Ch34: 20000 rows
# t=0: detections=200, links=0, new_tracks=200, active=200
# t=1: detections=200, links=124, new_tracks=76, active=276
# t=2: detections=200, links=146, new_tracks=54, active=330
# t=3: detections=200, links=177, new_tracks=23, active=345
# t=4: detections=200, links=168, new_tracks=32, active=361
# t=5: detections=200, links=186, new_tracks=14, active=353
# t=6: detections=200, links=174, new_tracks=26, active=357
# t=7: detections=200, links=178, new_tracks=22, active=343
# t=8: detections=200, links=171, new_tracks=29, active=353
# t=9: detections=200, links=179, new_tracks=21, active=354
# t=10: detections=200, links=175, new_tracks=25, active=348
# t=11: detections=200, links=171, new_tracks=29, active=357
# t=12: detections=200, links=171, new_tracks=29, active=368
# t=13: detections=200, links=171, new_tracks=29, active=368
# t=14: detections=200, links=173, new_tracks=27, active=368
# t=15: detections=200, links=186, new_tracks=14, active=354
# t=16: detections=200, links=163, new_tracks=37, active=361
# t=17: detections=200, links=178, new_tracks=22, active=351
# t=18: detections=200, links=183, new_tracks=17, active=330
# t=19: detections=200, links=168, new_tracks=32, active=340
# t=20: detections=200, links=169, new_tracks=31, active=348
# t=21: detections=200, links=167, new_tracks=33, active=360
# t=22: detections=200, links=173, new_tracks=27, active=361
# t=23: detections=200, links=178, new_tracks=22, active=362
# t=24: detections=200, links=173, new_tracks=27, active=359
# t=25: detections=200, links=173, new_tracks=27, active=366
# t=26: detections=200, links=181, new_tracks=19, active=355
# t=27: detections=200, links=173, new_tracks=27, active=348
# t=28: detections=200, links=174, new_tracks=26, active=352
# t=29: detections=200, links=168, new_tracks=32, active=361
# t=30: detections=200, links=174, new_tracks=26, active=352
# t=31: detections=200, links=166, new_tracks=34, active=347
# t=32: detections=200, links=168, new_tracks=32, active=351
# t=33: detections=200, links=178, new_tracks=22, active=352
# t=34: detections=200, links=175, new_tracks=25, active=359
# t=35: detections=200, links=169, new_tracks=31, active=368
# t=36: detections=200, links=175, new_tracks=25, active=363
# t=37: detections=200, links=175, new_tracks=25, active=364
# t=38: detections=200, links=175, new_tracks=25, active=359
# t=39: detections=200, links=185, new_tracks=15, active=346
# t=40: detections=200, links=168, new_tracks=32, active=359
# t=41: detections=200, links=173, new_tracks=27, active=368
# t=42: detections=200, links=169, new_tracks=31, active=372
# t=43: detections=200, links=186, new_tracks=14, active=362
# t=44: detections=200, links=176, new_tracks=24, active=353
# t=45: detections=200, links=160, new_tracks=40, active=366
# t=46: detections=200, links=167, new_tracks=33, active=364
# t=47: detections=200, links=177, new_tracks=23, active=356
# t=48: detections=200, links=165, new_tracks=35, active=368
# t=49: detections=200, links=174, new_tracks=26, active=367
# t=50: detections=200, links=159, new_tracks=41, active=367
# t=51: detections=200, links=173, new_tracks=27, active=371
# t=52: detections=200, links=172, new_tracks=28, active=360
# t=53: detections=200, links=183, new_tracks=17, active=353
# t=54: detections=200, links=181, new_tracks=19, active=354
# t=55: detections=200, links=183, new_tracks=17, active=344
# t=56: detections=200, links=174, new_tracks=26, active=347
# t=57: detections=200, links=162, new_tracks=38, active=366
# t=58: detections=200, links=169, new_tracks=31, active=378
# t=59: detections=200, links=185, new_tracks=15, active=360
# t=60: detections=200, links=176, new_tracks=24, active=365
# t=61: detections=200, links=174, new_tracks=26, active=367
# t=62: detections=200, links=167, new_tracks=33, active=370
# t=63: detections=200, links=163, new_tracks=37, active=384
# t=64: detections=200, links=185, new_tracks=15, active=372
# t=65: detections=200, links=171, new_tracks=29, active=378
# t=66: detections=200, links=171, new_tracks=29, active=371
# t=67: detections=200, links=180, new_tracks=20, active=364
# t=68: detections=200, links=169, new_tracks=31, active=374
# t=69: detections=200, links=168, new_tracks=32, active=368
# t=70: detections=200, links=171, new_tracks=29, active=380
# t=71: detections=200, links=173, new_tracks=27, active=378
# t=72: detections=200, links=171, new_tracks=29, active=374
# t=73: detections=200, links=173, new_tracks=27, active=378
# t=74: detections=200, links=172, new_tracks=28, active=379
# t=75: detections=200, links=179, new_tracks=21, active=379
# t=76: detections=200, links=173, new_tracks=27, active=375
# t=77: detections=200, links=175, new_tracks=25, active=376
# t=78: detections=200, links=163, new_tracks=37, active=377
# t=79: detections=200, links=169, new_tracks=31, active=376
# t=80: detections=200, links=176, new_tracks=24, active=376
# t=81: detections=200, links=166, new_tracks=34, active=376
# t=82: detections=200, links=181, new_tracks=19, active=362
# t=83: detections=200, links=172, new_tracks=28, active=361
# t=84: detections=200, links=176, new_tracks=24, active=367
# t=85: detections=200, links=165, new_tracks=35, active=372
# t=86: detections=200, links=174, new_tracks=26, active=373
# t=87: detections=200, links=168, new_tracks=32, active=381
# t=88: detections=200, links=172, new_tracks=28, active=378
# t=89: detections=200, links=165, new_tracks=35, active=386
# t=90: detections=200, links=176, new_tracks=24, active=378
# t=91: detections=200, links=164, new_tracks=36, active=391
# t=92: detections=200, links=179, new_tracks=21, active=382
# t=93: detections=200, links=177, new_tracks=23, active=379
# t=94: detections=200, links=178, new_tracks=22, active=370
# t=95: detections=200, links=170, new_tracks=30, active=372
# t=96: detections=200, links=171, new_tracks=29, active=376
# t=97: detections=200, links=166, new_tracks=34, active=380
# t=98: detections=200, links=160, new_tracks=40, active=408
# t=99: detections=200, links=171, new_tracks=29, active=400
# Ch35 adapter: received dict with keys: ['frame_summary', 'track_edges', 'track_nodes']
# Ch35 adapter: nodes='track_nodes', edges='track_edges', frame_summary='frame_summary'
# Ch35: 20000 nodes, 17037 edges, 2963 tracks
# Input relationship validated.
#      detection_id  t  track_id  num_detections  duration  track_path_efficiency  track_coverage_fraction
# 0  chapter34_t0_0  0         0               1         1               0.000000                 0.999999
# 1  chapter34_t0_1  0         1               9        17               0.605160                 0.529412
# 2  chapter34_t0_2  0         2               6         8               0.378698                 0.750000
# 3  chapter34_t0_3  0         3               5         9               0.672734                 0.555555
# 4  chapter34_t0_4  0         4               7        11               0.658356                 0.636364
#      detection_id  has_incoming_link  has_outgoing_link  two_sided_support  incoming_assignment_cost  outgoing_assignment_cost
# 0  chapter34_t0_0                  0                  0                  0                       NaN                       NaN
# 1  chapter34_t0_1                  0                  1                  0                       NaN                  2.972107
# 2  chapter34_t0_2                  0                  1                  0                       NaN                  2.297876
# 3  chapter34_t0_3                  0                  1                  0                       NaN                 12.642813
# 4  chapter34_t0_4                  0                  1                  0                       NaN                  2.237122
#      detection_id  previous_step_length  next_step_length  local_acceleration  direction_cosine
# 0  chapter34_t0_0                   NaN               NaN                 NaN               NaN
# 1  chapter34_t0_1                   NaN          1.990210                 NaN               NaN
# 2  chapter34_t0_2                   NaN          1.675012                 NaN               NaN
# 3  chapter34_t0_3                   NaN         11.497664                 NaN               NaN
# 4  chapter34_t0_4                   NaN          1.464755                 NaN               NaN
# 5  chapter34_t0_5                   NaN          2.725208                 NaN               NaN
# 6  chapter34_t0_6                   NaN          0.908403                 NaN               NaN
# 7  chapter34_t0_7                   NaN          1.723573                 NaN               NaN
# 8  chapter34_t0_8                   NaN          9.518742                 NaN               NaN
# 9  chapter34_t0_9                   NaN         10.413005                 NaN               NaN
#            detection_id   t  rank_position  num_detections  two_sided_support  temporal_support_score
# 9000    chapter34_t45_0  45              1              43                  1                0.828082
# 5603    chapter34_t28_3  28              4              28                  1                0.810194
# 10608   chapter34_t53_8  53              9              43                  1                0.783758
# 15403   chapter34_t77_3  77              4              36                  1                0.778927
# 7609    chapter34_t38_9  38             10              43                  1                0.774124
# 11008   chapter34_t55_8  55              9              43                  1                0.773816
# 4013   chapter34_t20_13  20             14              23                  1                0.771697
# 2402    chapter34_t12_2  12              3              17                  1                0.769780
# 3200    chapter34_t16_0  16              1              19                  1                0.763058
# 17207   chapter34_t86_7  86              8              36                  1                0.760410
# 16201   chapter34_t81_1  81              2              31                  1                0.759531
# 604      chapter34_t3_4   3              5              32                  1                0.753798
# 3623   chapter34_t18_23  18             24              23                  1                0.752854
# 10203   chapter34_t51_3  51              4              43                  1                0.750724
# 2238   chapter34_t11_38  11             39              41                  1                0.750498
# 1809     chapter34_t9_9   9             10              26                  1                0.749983
# 1200     chapter34_t6_0   6              1              15                  1                0.748106
# 11205   chapter34_t56_5  56              6              29                  1                0.747502
# 3601    chapter34_t18_1  18              2               8                  1                0.746902
# 15603   chapter34_t78_3  78              4              36                  1                0.745189
# Filtered detections: 5000
# Mean detections per frame: 50.0
#    t     detection_id   z    y    x  rank_position  filtered_rank_position  final_filter_score
# 0  0   chapter34_t0_6   9  202  241              7                       1            0.601492
# 1  0  chapter34_t0_14  24  167  206             15                       2            0.599213
# 2  0  chapter34_t0_17  39  113  169             18                       3            0.595387
# 3  0  chapter34_t0_23  12  220  181             24                       4            0.586542
# 4  0  chapter34_t0_11  15  186  164             12                       5            0.565993
# Filtered track nodes: 5000
# Filtered track edges: 2672
#     track_id  start_t  end_t  num_filtered_detections  filtered_duration  filtered_coverage_fraction  mean_rank_position  mean_pred_dist
# 0        721       21     68                       38                 48                    0.791667           82.842105       17.842669
# 1        453        8     60                       34                 53                    0.641509           78.029412       17.463854
# 2       1557       51     98                       32                 48                    0.666667           56.281250       17.826688
# 3        510       20     70                       28                 51                    0.549020           84.107143       18.021228
# 4        584       13     44                       24                 32                    0.750000           56.166667       16.645326
# 5       1808       59     99                       24                 41                    0.585366           82.708333       18.690166
# 6       1865       61     92                       23                 32                    0.718750           76.695652       18.595588
# 7       1594       52     81                       23                 30                    0.766667           54.043478       17.991556
# 8       1915       66     98                       22                 33                    0.666667           93.772727       18.874584
# 9       1649       55     87                       21                 33                    0.636364           68.904762       18.051004
# 10       946       27     69                       21                 43                    0.488372           76.952381       18.002981
# 11      1642       55     99                       21                 45                    0.466667           58.571429       17.895326
# 12      1044       32     58                       21                 27                    0.777778           68.904762       17.755981
# 13       919       27     63                       21                 37                    0.567568           78.666667       18.023648
# 14      1350       42     80                       19                 39                    0.487179           83.368421       18.436790
# 15        94        5     45                       18                 41                    0.439024           91.555556       17.390539
# 16      2036       68     99                       18                 32                    0.562500           49.555556       18.110192
# 17      1066       33     68                       18                 36                    0.500000           61.833333       17.489192
# 18       201        1     42                       18                 42                    0.428571           71.333333       16.681183
# 19       948       28     60                       17                 33                    0.515152           77.823529       17.714531
# 20      1601       51     76                       17                 26                    0.653846           41.941176       17.839807
# 21       469       12     46                       17                 35                    0.485714           73.176471       16.904080
# 22       888       25     43                       17                 19                    0.894737           67.764706       17.343836
# 23       832       26     50                       17                 25                    0.680000           75.176471       17.464697
# 24       568       13     44                       16                 32                    0.500000           57.125000       16.732156
# 25      1962       66     91                       16                 26                    0.615385           50.250000       18.114033
# 26      1392       44     68                       16                 25                    0.640000           50.875000       17.359484
# 27      1385       44     64                       16                 21                    0.761905           60.875000       17.729144
# 28      2112       70     89                       16                 20                    0.800000           81.562500       18.296038
# 29       920       30     50                       16                 21                    0.761905           40.500000       16.605332
# Ch36: 5000 rows | historical_label_free_temporal_support
# clean nodes 4574 clean edges 2672 tracks 919
#      track_id  start_t  end_t  num_detections  start_z    start_y   start_x   end_z      end_y     end_x  start_vz  start_vy  start_vx   end_vz    end_vy    end_vx  mean_rank  \
# 265       721       21     68              38   39.000   71.50000  80.84375  42.250   73.12500   9.34375  -1.62500  0.541667 -2.166667 -6.50000  6.093750 -5.890625  82.842105
# 169       453        8     60              34   65.000   32.90625  81.25000  94.250    2.84375  46.31250  -2.43750 -0.812500 -0.406250  1.62500  0.000000 -0.812500  78.029412
# 525      1557       51     98              32   17.875   95.06250  73.93750  52.000   45.09375   7.71875  -1.62500 -1.218750 -2.843750  0.81250 -5.281250  0.406250  56.281250
# 183       510       20     70              28   82.875   27.21875  56.46875  87.750    0.00000  21.93750  -3.90000  2.600000  3.818750 -0.81250 -1.625000 -3.250000  84.107143
# 209       584       13     44              24   73.125   26.81250  58.90625  97.500   10.96875  24.78125   0.00000 -1.625000  1.218750  1.62500  0.000000 -2.843750  56.166667
# 604      1808       59     99              24   21.125   87.34375  30.87500  35.750   67.84375  15.03125   1.62500  0.000000 -1.218750 -1.62500 -1.218750 -1.218750  82.708333
# 621      1865       61     92              23   34.125   77.18750  79.21875  48.750   59.31250   0.40625   0.00000 -1.218750 -0.406250  1.62500 -0.812500 -2.031250  76.695652
# 537      1594       52     81              23    8.125  101.56250  99.53125  11.375  103.59375  53.21875   0.00000  0.000000 -1.421875  3.25000  0.000000 -2.437500  54.043478
# 631      1915       66     98              22   47.125   62.56250  58.09375  53.625   54.03125   2.84375   2.43750  0.000000 -1.218750  1.62500 -0.812500 -4.875000  93.772727
# 365      1044       32     58              21   60.125   49.15625  52.81250  73.125   37.37500  32.90625   1.62500 -1.625000 -2.437500  0.00000  6.093750  0.000000  68.904762
# 552      1642       55     99              21   43.875   73.12500  58.09375   8.125   94.25000  35.34375   0.00000  0.000000 -1.218750  0.00000  0.000000 -2.031250  58.571429
# 332       946       27     69              21   29.250   84.09375  49.56250  73.125   30.46875  14.62500  -1.62500 -2.437500  1.625000  6.50000 -8.734375  3.250000  76.952381
# 319       919       27     63              21   39.000   45.50000  76.78125  84.500   14.21875   5.68750   1.62500  0.812500 -1.625000 -1.62500 -1.218750  0.000000  78.666667
# 555      1649       55     87              21   40.625   74.34375  58.09375  60.125   47.12500  23.15625   0.00000  0.000000 -0.812500  2.03125 -3.250000  3.859375  68.904762
# 456      1350       42     80              19   29.250   91.00000   7.71875  81.250   21.93750  27.62500   0.00000 -0.609375 -1.828125  4.06250 -5.958333  4.401042  83.368421
# 87        201        1     42              18   61.750   45.09375  80.03125  71.500   28.03125  53.21875   0.00000  0.812500  0.000000 -1.62500 -0.812500 -2.437500  71.333333
# 374      1066       33     68              18   53.625   48.34375  74.75000  78.000   18.28125  12.18750  -1.62500  0.000000 -0.406250  0.00000 -2.031250 -4.468750  61.833333
# 54         94        5     45              18   26.000   84.50000  71.09375  29.250   78.40625  32.09375  -0.81250 -0.406250 -1.218750  1.62500  0.406250 -6.093750  91.555556
# 672      2036       68     99              18   13.000   97.09375  93.03125  53.625   62.96875  17.87500  -2.84375  1.625000 -4.671875  6.50000 -3.250000 -1.625000  49.555556
# 290       832       26     50              17   65.000   49.56250  94.65625  65.000   36.56250  64.18750   1.62500  0.406250  0.000000  0.00000  0.000000 -2.031250  75.176471
#
#      mean_pred_dist
# 265       17.842669
# 169       17.463854
# 525       17.826688
# 183       18.021228
# 209       16.645326
# 604       18.690166
# 621       18.595588
# 537       17.991556
# 631       18.874584
# 365       17.755981
# 552       17.895326
# 332       18.002981
# 319       18.023648
# 555       18.051004
# 456       18.436790
# 87        16.681183
# 374       17.489192
# 54        17.390539
# 672       18.110192
# 290       17.464697
# gap links 415
#     source_track_id  target_track_id  source_end_t  target_start_t  frame_gap  gap_closing_cost
# 0                 1              338             8               9          1          7.927711
# 1                 4              355             3               4          1          3.611866
# 2                 6               84             4               7          3         12.669202
# 3                10              630            14              16          2         13.466077
# 4                14              721            18              21          3         24.074383
# 5                16              293             3               5          2         10.203363
# 6                18              383             4               6          2         14.534516
# 7                19              958            26              28          2         11.944899
# 8                22              359             7              10          3         14.999887
# 9                23               94             3               5          2         10.781965
# 10               24              144             1               3          2         12.272168
# 11               41             1201            34              37          3         10.163661
# 12               43              109             1               4          3         15.675282
# 13               45              561            12              13          1          6.061875
# 14               46              295             2               4          2         13.028541
# 15               54              346             3               6          3         10.060186
# 16               55              834            21              23          2         14.748487
# 17               60              366             2               5          3         17.769428
# 18               63              845            21              23          2         17.509607
# 19               64               71             2               5          3         21.945505
# before 919 after 504
# nodes 4574 edges 3087 tracks 504
#    track_id source_detection_id target_detection_id  source_t  target_t  frame_gap  assignment_cost  original_track_id    edge_type
# 0         0     chapter34_t6_76    chapter34_t8_112         6         8          2         1.989864                  1     original
# 1         0    chapter34_t8_112     chapter34_t9_38         8         9          1         7.927711                  1  gap_closing
# 2         0     chapter34_t9_38    chapter34_t10_31         9        10          1         4.025278                338     original
# 3         0    chapter34_t14_48    chapter34_t15_26        14        15          1         4.340210                338     original
# 4         0    chapter34_t15_26    chapter34_t17_21        15        17          2         9.943437                338     original
#                 stage  track_nodes  track_edges  num_tracks  mean_track_length  max_track_length
# 0  chapter36_filtered         5000         2672        1345           3.717472                38
# 1   chapter37_refined         4574         3087         504           9.075397                51
#     track_id  start_t  end_t  num_detections  duration  coverage_fraction  mean_rank  mean_pred_dist  path_length_physical  net_displacement_physical  path_efficiency
# 0          9        0     68              51        69           0.739130  77.235294       17.245588            197.957748                  74.601929         0.376858
# 1         66        4     60              36        57           0.631579  74.861111       17.288810            138.849213                  62.932045         0.453240
# 2         78        1     77              36        77           0.467532  62.805556       17.353646            247.477158                  91.799019         0.370939
# 3        125        8     70              35        63           0.555556  75.628571       17.540136            203.115845                  63.110123         0.310710
# 4        186       22     87              34        66           0.515152  55.882353       17.749506            166.789551                  73.297455         0.439461
# 5        316       52     99              33        48           0.687500  62.727273       18.238786            154.699142                  82.245308         0.531647
# 6         94        7     82              33        76           0.434211  48.272727       17.159089            317.127686                  49.922489         0.157421
# 7        306       51     98              32        48           0.666667  56.281250       17.826688            162.190903                  89.701248         0.553060
# 8         98        6     76              31        71           0.436620  50.451613       16.842308            171.861053                  81.777428         0.475835
# 9        211       28     99              31        72           0.430556  52.677419       17.605021            259.975983                 122.054298         0.469483
# 10       287       49     95              30        47           0.638298  66.833333       18.129177            183.083191                 110.060768         0.601152
# 11       233       33     95              30        63           0.476190  37.066667       17.254692            186.084030                  47.822029         0.256992
# 12       181       22     92              30        71           0.422535  46.933333       17.624729            241.383270                  95.118042         0.394054
# 13       247       40     99              29        60           0.483333  53.758621       17.801447            190.286835                  72.368393         0.380312
# 14       154       13     48              28        36           0.777778  59.250000       16.837920             93.609001                  58.103691         0.620706
# 15       262       43     91              28        49           0.571429  54.142857       17.776360            148.284927                  47.820301         0.322489
# 16       313       52     93              27        42           0.642857  57.000000       18.135156            159.126602                  55.547909         0.349080
# 17       317       51     95              27        45           0.600000  34.962963       17.671954            151.070770                  98.252884         0.650377
# 18        16        0     68              27        69           0.391304  45.777778       16.194091            213.519318                 106.670609         0.499583
# 19       134       11     41              26        31           0.838710  75.538462       16.540432             68.891312                  25.955528         0.376761
# 20       302       54     99              26        46           0.565217  77.038462       18.523820            126.529808                  28.509953         0.225322
# 21       122        5     51              26        47           0.553191  46.230769       15.861080            171.593369                  58.716827         0.342186
# 22       171       20     72              26        53           0.490566  33.961538       16.302423            171.652283                 103.927773         0.605455
# 23       102        6     74              26        69           0.376812  54.461538       16.708196            230.375031                  59.718750         0.259224
# 24       111        5     41              24        37           0.648649  35.916667       15.256374            104.095512                  51.791698         0.497540
# 25       129        7     44              24        38           0.631579  61.250000       16.662015             83.537338                  11.316815         0.135470
# 26       314       52     91              24        40           0.600000  45.125000       18.021762            145.164841                  88.615593         0.610448
# 27       226       34     78              24        45           0.533333  67.625000       18.182838            125.496994                  75.999161         0.605586
# 28        10        0     51              24        52           0.461538  40.916667       16.300004            173.707932                  71.493073         0.411571
# 29       146       12     75              24        64           0.375000  63.833333       17.380611            196.424088                  42.034607         0.213999
# Ch37: 4574 nodes, 504 tracks
#
# ==========================================================================================
# SAMPLE: 6bba_09961292 | GT binary divisions: 4
# Ch34 sample: 6bba_09961292
#   zarr: /kaggle/input/competitions/biohub-cell-tracking-during-development/train/6bba_09961292.zarr
#   raw volume shape: (100, 64, 256, 256)
#   timepoints: 100
#   config sample_id: 6bba_09961292
# t=0: raw=3241, nms=821, ranked=821, selected=200, time=5.4s
# t=1: raw=3367, nms=819, ranked=819, selected=200, time=5.6s
# t=2: raw=3136, nms=799, ranked=799, selected=200, time=5.5s
# t=3: raw=3261, nms=817, ranked=817, selected=200, time=5.6s
# t=4: raw=3141, nms=818, ranked=818, selected=200, time=5.5s
# t=5: raw=3080, nms=780, ranked=780, selected=200, time=5.6s
# t=6: raw=2958, nms=777, ranked=777, selected=200, time=5.4s
# t=7: raw=3100, nms=805, ranked=805, selected=200, time=5.6s
# t=8: raw=3134, nms=816, ranked=816, selected=200, time=5.6s
# t=9: raw=3346, nms=846, ranked=846, selected=200, time=5.6s
# t=10: raw=3482, nms=880, ranked=880, selected=200, time=5.5s
# t=11: raw=3150, nms=830, ranked=830, selected=200, time=5.5s
# t=12: raw=3141, nms=762, ranked=762, selected=200, time=5.5s
# t=13: raw=3177, nms=828, ranked=828, selected=200, time=5.5s
# t=14: raw=3415, nms=831, ranked=831, selected=200, time=5.7s
# t=15: raw=3465, nms=846, ranked=846, selected=200, time=5.5s
# t=16: raw=3319, nms=852, ranked=852, selected=200, time=5.5s
# t=17: raw=3396, nms=851, ranked=851, selected=200, time=5.6s
# t=18: raw=3391, nms=825, ranked=825, selected=200, time=5.6s
# t=19: raw=3349, nms=826, ranked=826, selected=200, time=5.5s
# t=20: raw=3090, nms=792, ranked=792, selected=200, time=5.4s
# t=21: raw=3153, nms=797, ranked=797, selected=200, time=5.5s
# t=22: raw=3241, nms=768, ranked=768, selected=200, time=5.5s
# t=23: raw=2958, nms=751, ranked=751, selected=200, time=5.4s
# t=24: raw=2973, nms=732, ranked=732, selected=200, time=5.6s
# t=25: raw=2977, nms=743, ranked=743, selected=200, time=5.5s
# t=26: raw=2803, nms=689, ranked=689, selected=200, time=5.4s
# t=27: raw=2803, nms=689, ranked=689, selected=200, time=5.4s
# t=28: raw=2855, nms=729, ranked=729, selected=200, time=5.4s
# t=29: raw=2814, nms=722, ranked=722, selected=200, time=5.4s
# t=30: raw=2847, nms=697, ranked=697, selected=200, time=5.4s
# t=31: raw=3107, nms=754, ranked=754, selected=200, time=5.4s
# t=32: raw=2853, nms=724, ranked=724, selected=200, time=5.4s
# t=33: raw=2867, nms=741, ranked=741, selected=200, time=5.4s
# t=34: raw=3011, nms=764, ranked=764, selected=200, time=5.5s
# t=35: raw=3011, nms=764, ranked=764, selected=200, time=5.6s
# t=36: raw=2984, nms=731, ranked=731, selected=200, time=5.4s
# t=37: raw=2904, nms=733, ranked=733, selected=200, time=5.5s
# t=38: raw=2779, nms=717, ranked=717, selected=200, time=5.4s
# t=39: raw=1951, nms=508, ranked=508, selected=200, time=5.2s
# t=40: raw=2772, nms=665, ranked=665, selected=200, time=5.4s
# t=41: raw=2634, nms=636, ranked=636, selected=200, time=5.4s
# t=42: raw=2717, nms=671, ranked=671, selected=200, time=5.3s
# t=43: raw=2755, nms=667, ranked=667, selected=200, time=5.4s
# t=44: raw=2673, nms=645, ranked=645, selected=200, time=5.3s
# t=45: raw=2635, nms=663, ranked=663, selected=200, time=5.3s
# t=46: raw=2603, nms=659, ranked=659, selected=200, time=5.2s
# t=47: raw=2628, nms=651, ranked=651, selected=200, time=5.3s
# t=48: raw=2565, nms=637, ranked=637, selected=200, time=5.4s
# t=49: raw=2627, nms=669, ranked=669, selected=200, time=5.3s
# t=50: raw=2627, nms=669, ranked=669, selected=200, time=5.4s
# t=51: raw=2614, nms=653, ranked=653, selected=200, time=5.3s
# t=52: raw=2755, nms=669, ranked=669, selected=200, time=5.4s
# t=53: raw=2732, nms=655, ranked=655, selected=200, time=5.3s
# t=54: raw=2713, nms=653, ranked=653, selected=200, time=5.4s
# t=55: raw=2622, nms=644, ranked=644, selected=200, time=5.3s
# t=56: raw=2538, nms=645, ranked=645, selected=200, time=5.3s
# t=57: raw=2389, nms=607, ranked=607, selected=200, time=5.3s
# t=58: raw=2442, nms=602, ranked=602, selected=200, time=5.3s
# t=59: raw=2355, nms=570, ranked=570, selected=200, time=5.2s
# t=60: raw=2465, nms=604, ranked=604, selected=200, time=5.2s
# t=61: raw=2517, nms=617, ranked=617, selected=200, time=5.4s
# t=62: raw=2481, nms=617, ranked=617, selected=200, time=5.3s
# t=63: raw=2612, nms=653, ranked=653, selected=200, time=5.3s
# t=64: raw=2720, nms=636, ranked=636, selected=200, time=5.3s
# t=65: raw=2720, nms=636, ranked=636, selected=200, time=5.3s
# t=66: raw=2376, nms=614, ranked=614, selected=200, time=5.2s
# t=67: raw=2482, nms=641, ranked=641, selected=200, time=5.3s
# t=68: raw=2433, nms=597, ranked=597, selected=200, time=5.2s
# t=69: raw=2595, nms=631, ranked=631, selected=200, time=5.3s
# t=70: raw=2618, nms=648, ranked=648, selected=200, time=5.3s
# t=71: raw=2652, nms=650, ranked=650, selected=200, time=5.3s
# t=72: raw=2606, nms=637, ranked=637, selected=200, time=5.3s
# t=73: raw=2712, nms=677, ranked=677, selected=200, time=5.3s
# t=74: raw=2604, nms=664, ranked=664, selected=200, time=5.5s
# t=75: raw=2604, nms=664, ranked=664, selected=200, time=5.3s
# t=76: raw=2612, nms=659, ranked=659, selected=200, time=5.3s
# t=77: raw=2617, nms=641, ranked=641, selected=200, time=5.3s
# t=78: raw=2420, nms=618, ranked=618, selected=200, time=5.3s
# t=79: raw=2685, nms=652, ranked=652, selected=200, time=5.4s
# t=80: raw=2685, nms=652, ranked=652, selected=200, time=5.3s
# t=81: raw=2242, nms=574, ranked=574, selected=200, time=5.2s
# t=82: raw=2242, nms=574, ranked=574, selected=200, time=5.2s
# t=83: raw=2404, nms=613, ranked=613, selected=200, time=5.3s
# t=84: raw=2335, nms=598, ranked=598, selected=200, time=5.3s
# t=85: raw=2335, nms=598, ranked=598, selected=200, time=5.2s
# t=86: raw=2297, nms=568, ranked=568, selected=200, time=5.3s
# t=87: raw=2392, nms=615, ranked=615, selected=200, time=5.3s
# t=88: raw=2513, nms=639, ranked=639, selected=200, time=5.3s
# t=89: raw=2513, nms=639, ranked=639, selected=200, time=5.2s
# t=90: raw=2573, nms=640, ranked=640, selected=200, time=5.5s
# t=91: raw=2461, nms=612, ranked=612, selected=200, time=5.2s
# t=92: raw=2425, nms=603, ranked=603, selected=200, time=5.3s
# t=93: raw=1924, nms=489, ranked=489, selected=200, time=5.2s
# t=94: raw=2411, nms=572, ranked=572, selected=200, time=5.3s
# t=95: raw=2301, nms=569, ranked=569, selected=200, time=5.2s
# t=96: raw=2272, nms=584, ranked=584, selected=200, time=5.3s
# t=97: raw=2354, nms=593, ranked=593, selected=200, time=5.3s
# t=98: raw=2415, nms=621, ranked=621, selected=200, time=5.3s
# t=99: raw=2415, nms=621, ranked=621, selected=200, time=5.3s
# Ch34 adapter: received dict with keys: ['frame_summary', 'full_ranked_candidates', 'selected_detections']
# Ch34 adapter: using DataFrame from result['selected_detections']
# Ch34: 20000 rows
# t=0: detections=200, links=0, new_tracks=200, active=200
# t=1: detections=200, links=97, new_tracks=103, active=303
# t=2: detections=200, links=155, new_tracks=45, active=348
# t=3: detections=200, links=166, new_tracks=34, active=371
# t=4: detections=200, links=179, new_tracks=21, active=364
# t=5: detections=200, links=180, new_tracks=20, active=365
# t=6: detections=200, links=169, new_tracks=31, active=377
# t=7: detections=200, links=169, new_tracks=31, active=380
# t=8: detections=200, links=172, new_tracks=28, active=379
# t=9: detections=200, links=169, new_tracks=31, active=389
# t=10: detections=200, links=179, new_tracks=21, active=385
# t=11: detections=200, links=172, new_tracks=28, active=378
# t=12: detections=200, links=151, new_tracks=49, active=393
# t=13: detections=200, links=171, new_tracks=29, active=382
# t=14: detections=200, links=163, new_tracks=37, active=389
# t=15: detections=200, links=174, new_tracks=26, active=380
# t=16: detections=200, links=168, new_tracks=32, active=376
# t=17: detections=200, links=175, new_tracks=25, active=378
# t=18: detections=200, links=171, new_tracks=29, active=369
# t=19: detections=200, links=179, new_tracks=21, active=358
# t=20: detections=200, links=152, new_tracks=48, active=387
# t=21: detections=200, links=183, new_tracks=17, active=374
# t=22: detections=200, links=164, new_tracks=36, active=376
# t=23: detections=200, links=160, new_tracks=40, active=383
# t=24: detections=200, links=174, new_tracks=26, active=371
# t=25: detections=200, links=159, new_tracks=41, active=385
# t=26: detections=200, links=174, new_tracks=26, active=377
# t=27: detections=200, links=194, new_tracks=6, active=336
# t=28: detections=200, links=176, new_tracks=24, active=329
# t=29: detections=200, links=154, new_tracks=46, active=360
# t=30: detections=200, links=178, new_tracks=22, active=358
# t=31: detections=200, links=170, new_tracks=30, active=359
# t=32: detections=200, links=175, new_tracks=25, active=368
# t=33: detections=200, links=173, new_tracks=27, active=369
# t=34: detections=200, links=183, new_tracks=17, active=359
# t=35: detections=200, links=196, new_tracks=4, active=323
# t=36: detections=200, links=168, new_tracks=32, active=321
# t=37: detections=200, links=175, new_tracks=25, active=336
# t=38: detections=200, links=178, new_tracks=22, active=339
# t=39: detections=200, links=154, new_tracks=46, active=365
# t=40: detections=200, links=173, new_tracks=27, active=376
# t=41: detections=200, links=178, new_tracks=22, active=368
# t=42: detections=200, links=178, new_tracks=22, active=362
# t=43: detections=200, links=175, new_tracks=25, active=356
# t=44: detections=200, links=179, new_tracks=21, active=350
# t=45: detections=200, links=165, new_tracks=35, active=357
# t=46: detections=200, links=178, new_tracks=22, active=349
# t=47: detections=200, links=178, new_tracks=22, active=351
# t=48: detections=200, links=176, new_tracks=24, active=353
# t=49: detections=200, links=170, new_tracks=30, active=358
# t=50: detections=200, links=198, new_tracks=2, active=318
# t=51: detections=200, links=155, new_tracks=45, active=340
# t=52: detections=200, links=177, new_tracks=23, active=348
# t=53: detections=200, links=186, new_tracks=14, active=340
# t=54: detections=200, links=179, new_tracks=21, active=340
# t=55: detections=200, links=181, new_tracks=19, active=348
# t=56: detections=200, links=183, new_tracks=17, active=346
# t=57: detections=200, links=179, new_tracks=21, active=344
# t=58: detections=200, links=183, new_tracks=17, active=337
# t=59: detections=200, links=181, new_tracks=19, active=339
# t=60: detections=200, links=185, new_tracks=15, active=340
# t=61: detections=200, links=176, new_tracks=24, active=340
# t=62: detections=200, links=175, new_tracks=25, active=336
# t=63: detections=200, links=175, new_tracks=25, active=338
# t=64: detections=200, links=190, new_tracks=10, active=331
# t=65: detections=200, links=197, new_tracks=3, active=302
# t=66: detections=200, links=156, new_tracks=44, active=331
# t=67: detections=200, links=179, new_tracks=21, active=337
# t=68: detections=200, links=181, new_tracks=19, active=338
# t=69: detections=200, links=184, new_tracks=16, active=335
# t=70: detections=200, links=186, new_tracks=14, active=328
# t=71: detections=200, links=171, new_tracks=29, active=340
# t=72: detections=200, links=173, new_tracks=27, active=343
# t=73: detections=200, links=179, new_tracks=21, active=338
# t=74: detections=200, links=179, new_tracks=21, active=342
# t=75: detections=200, links=195, new_tracks=5, active=311
# t=76: detections=200, links=165, new_tracks=35, active=324
# t=77: detections=200, links=173, new_tracks=27, active=339
# t=78: detections=200, links=190, new_tracks=10, active=335
# t=79: detections=200, links=181, new_tracks=19, active=335
# t=80: detections=200, links=197, new_tracks=3, active=298
# t=81: detections=200, links=166, new_tracks=34, active=307
# t=82: detections=200, links=192, new_tracks=8, active=306
# t=83: detections=200, links=191, new_tracks=9, active=304
# t=84: detections=200, links=172, new_tracks=28, active=319
# t=85: detections=200, links=199, new_tracks=1, active=291
# t=86: detections=200, links=180, new_tracks=20, active=292
# t=87: detections=200, links=177, new_tracks=23, active=312
# t=88: detections=200, links=150, new_tracks=50, active=355
# t=89: detections=200, links=199, new_tracks=1, active=318
# t=90: detections=200, links=185, new_tracks=15, active=305
# t=91: detections=200, links=182, new_tracks=18, active=312
# t=92: detections=200, links=177, new_tracks=23, active=327
# t=93: detections=200, links=165, new_tracks=35, active=348
# t=94: detections=200, links=177, new_tracks=23, active=357
# t=95: detections=200, links=183, new_tracks=17, active=359
# t=96: detections=200, links=191, new_tracks=9, active=327
# t=97: detections=200, links=175, new_tracks=25, active=329
# t=98: detections=200, links=183, new_tracks=17, active=324
# t=99: detections=200, links=192, new_tracks=8, active=299
# Ch35 adapter: received dict with keys: ['frame_summary', 'track_edges', 'track_nodes']
# Ch35 adapter: nodes='track_nodes', edges='track_edges', frame_summary='frame_summary'
# Ch35: 20000 nodes, 17374 edges, 2626 tracks
# Input relationship validated.
#      detection_id  t  track_id  num_detections  duration  track_path_efficiency  track_coverage_fraction
# ...
# 6        934       52     91                       32                 40                    0.800000           51.562500       18.869666
# 7        292        4     76                       31                 73                    0.424658           69.322581       19.414812
# 8        671       28     77                       29                 50                    0.580000           72.241379       19.517140
# 9        921       46     99                       28                 54                    0.518519           70.428571       19.228962
# 10       608       24     76                       27                 53                    0.509434           82.703704       19.568371
# 11       773       39     95                       26                 57                    0.456140           76.538462       19.525508
# 12       597       24     70                       25                 47                    0.531915           59.800000       19.390234
# 13       417       12     88                       25                 77                    0.324675           59.040000       19.411068
# 14      1042       56     95                       25                 40                    0.625000           65.880000       19.124165
# 15       913       46     84                       24                 39                    0.615385           83.791667       19.608968
# 16       676       30     92                       24                 63                    0.380952           69.750000       19.499037
# 17       892       45     99                       24                 55                    0.436364           87.791667       19.610527
# 18       419       12     54                       24                 43                    0.558140           60.583333       19.376644
# 19       649       31     72                       23                 42                    0.547619           53.391304       19.121357
# 20       391       13     43                       22                 31                    0.709677           71.681818       19.502998
# 21       427       12     54                       22                 43                    0.511628           67.409091       19.453345
# 22       596       23     58                       21                 36                    0.583333           74.428571       19.480415
# 23       106        4     49                       21                 46                    0.456522           88.047619       19.535349
# 24       910       45     97                       20                 53                    0.377358           81.800000       19.570445
# 25       701       29     86                       20                 58                    0.344828           62.750000       19.413776
# 26       420       14     45                       19                 32                    0.593750           90.368421       19.604115
# 27       324        9     52                       19                 44                    0.431818           74.263158       19.537295
# 28       744       31     72                       19                 42                    0.452381           71.526316       19.501510
# 29       678       31     56                       18                 26                    0.692308           59.944444       19.350694
# Ch36: 5000 rows | historical_label_free_temporal_support
# clean nodes 4722 clean edges 2349 tracks 776
#      track_id  start_t  end_t  num_detections  start_z   start_y    start_x   end_z     end_y     end_x  start_vz  start_vy  start_vx    end_vz    end_vy    end_vx  mean_rank  \
# 27         48        0     96              64  102.375  61.75000   93.03125  50.375  60.12500  33.71875 -3.250000  3.250000 -0.406250  2.437500 -2.031250 -3.859375  77.343750
# 186       381       10     86              50   69.875  54.43750   55.25000  11.375  58.90625  15.43750 -4.875000 -0.406250  2.437500  1.625000  0.677083  2.234375  66.100000
# 218       428       12     90              37   69.875  67.03125   70.28125  14.625  59.31250  16.65625 -3.250000  0.406250  0.812500  0.000000  0.406250  0.812500  98.837838
# 293       584       23     84              36  102.375  57.28125   78.40625  89.375  43.06250  14.21875  0.000000  0.000000  0.000000 -8.125000 -0.406250 -3.656250  65.694444
# 138       284        5     99              35   60.125  61.34375   32.90625  29.250  57.28125  13.00000  0.000000  1.218750  1.625000 -2.785714 -0.116071 -2.495536  87.200000
# 416       856       43     98              32   95.875  58.90625   91.40625  84.500  46.71875  15.03125  1.625000  0.000000  0.812500  0.000000  0.000000  0.000000  70.218750
# 460       934       52     91              32   95.875  47.93750   39.40625  97.500  39.00000   5.68750  4.875000 -0.406250  0.000000 -2.437500 -0.203125 -1.218750  51.562500
# 143       292        4     76              31   97.500  51.59375   89.78125   9.750  67.03125  42.65625  0.000000  0.203125  0.609375 -4.875000  0.000000 -2.437500  69.322581
# 326       671       28     77              29   50.375  71.50000  103.59375   6.500  73.12500  78.81250  0.541667 -0.270833  0.000000  0.812500  1.218750  3.250000  72.241379
# 455       921       46     99              28  100.750  57.68750   90.59375  74.750  56.87500  34.93750 -1.950000  0.406250 -0.081250  0.000000  0.000000  0.000000  70.428571
# 305       608       24     76              27    9.750  70.28125   53.21875  60.125  46.31250   4.06250  0.000000  0.000000  0.000000  0.000000 -0.406250  0.000000  82.703704
# 373       773       39     95              26   71.500  60.93750   62.96875   4.875  58.09375   5.68750 -3.250000 -0.406250 -0.406250 -1.625000  0.812500 -1.218750  76.538462
# 530      1042       56     95              25   95.875  43.87500   27.21875  69.875  48.34375  12.59375  1.625000  0.000000  1.218750 -1.625000  0.812500  2.843750  65.880000
# 209       417       12     88              25  102.375  53.21875   55.65625  74.750  60.12500  63.37500 -1.625000  0.541667 -1.083333  0.000000  0.000000 -1.625000  59.040000
# 301       597       24     70              25   99.125  62.96875   96.68750  29.250  47.53125  29.25000  0.000000  0.000000  0.000000  0.000000  0.406250  0.406250  59.800000
# 438       892       45     99              24   60.125  52.00000   49.56250  17.875  48.34375   9.34375 -0.406250  0.304688  0.914062 -1.625000 -0.406250 -1.015625  87.791667
# 449       913       46     84              24   66.625  56.87500   41.84375  24.375  58.90625  23.15625 -1.625000  0.162500 -0.975000 -2.437500  0.000000  0.406250  83.791667
# 211       419       12     54              24   99.125  56.87500   52.81250  21.125  56.46875  11.37500 -3.250000  0.812500  1.218750  0.000000  0.000000  0.000000  60.583333
# 329       676       30     92              24   56.875  69.06250   75.56250  43.875  51.59375   2.03125 -1.625000  1.218750 -0.406250  1.625000 -1.218750 -2.843750  69.750000
# 320       649       31     72              23   22.750  52.40625   26.81250  48.750  55.25000  19.09375  0.000000 -0.812500 -2.437500  6.229167 -0.067708  1.760417  53.391304
#
#      mean_pred_dist
# 27        19.527699
# 186       19.391981
# 218       19.644515
# 293       19.273255
# 138       19.521047
# 416       19.422529
# 460       18.869666
# 143       19.414812
# 326       19.517140
# 455       19.228962
# 305       19.568371
# 373       19.525508
# 530       19.124165
# 209       19.411068
# 301       19.390234
# 438       19.610527
# 449       19.608968
# 211       19.376644
# 329       19.499037
# 320       19.121357
# gap links 341
#     source_track_id  target_track_id  source_end_t  target_start_t  frame_gap  gap_closing_cost
# 0                 0              220             9              12          3         13.145840
# 1                14              106             1               4          3         10.025992
# 2                15              427            10              12          2          3.441955
# 3                16              428            10              12          2         18.109903
# 4                17              244             3               6          3          8.740501
# 5                20              588            20              23          3         21.266088
# 6                21              119             2               5          3         15.938018
# 7                24              227             2               5          3         24.653557
# 8                25              200             2               4          2          8.287292
# 9                28              255             1               3          2         19.386812
# 10               31              175             1               3          2          6.429296
# 11               35              533            17              20          3          5.664725
# 12               36              799            35              38          3         23.638222
# 13               39                1             1               3          2         12.701119
# 14               42              240             1               2          1          6.718367
# 15               44              156             1               4          3         15.795353
# 16               46              268             4               6          2         10.744851
# 17               51              344             5               8          3         20.954481
# 18               54              343             6               8          2         13.532117
# 19               55              324             7               9          2         14.241463
# before 776 after 435
# nodes 4722 edges 2690 tracks 435
#    track_id source_detection_id target_detection_id  source_t  target_t  frame_gap  assignment_cost  original_track_id edge_type
# 0         0      chapter34_t0_0     chapter34_t1_33         0         1          1         2.531307                  0  original
# 1         0     chapter34_t1_33     chapter34_t2_69         1         2          1         2.596481                  0  original
# 2         0     chapter34_t2_69     chapter34_t3_43         2         3          1         4.317001                  0  original
# 3         0     chapter34_t3_43     chapter34_t4_57         3         4          1         3.294983                  0  original
# 4         0    chapter34_t7_139     chapter34_t8_78         7         8          1         1.332479                  0  original
#                 stage  track_nodes  track_edges  num_tracks  mean_track_length  max_track_length
# 0  chapter36_filtered         5000         2349        1054           4.743833                64
# 1   chapter37_refined         4722         2690         435          10.855172                64
#     track_id  start_t  end_t  num_detections  duration  coverage_fraction  mean_rank  mean_pred_dist  path_length_physical  net_displacement_physical  path_efficiency
# 0         23        0     96              64        97           0.659794  77.343750       19.527699            300.856628                  78.896217         0.262239
# 1        141       10     94              56        85           0.658824  62.285714       19.321994            243.079773                  72.528992         0.298375
# 2        197       23     96              44        74           0.594595  66.522727       19.303840            159.917740                  80.749786         0.504946
# 3         53        3     79              39        77           0.506494  52.615385       19.356104            222.325211                  77.704277         0.349507
# 4          7        0     90              39        91           0.428571  94.743590       19.609612            251.626511                  86.867233         0.345223
# 5        246       35     91              37        57           0.649123  49.945946       18.822104            107.908577                  27.048441         0.250661
# 6         92        2     99              37        98           0.377551  86.486486       19.521786            289.843719                  31.765530         0.109595
# 7        149       13     92              35        80           0.437500  59.971429       19.354839            257.462280                  88.954834         0.345506
# 8         65        4     66              34        63           0.539683  54.323529       19.368777            201.537292                  82.158981         0.407661
# 9        165       21     85              34        65           0.523077  67.911765       19.492193            156.747299                  56.275524         0.359021
# 10       211       31     98              34        68           0.500000  50.352941       19.179463            178.123993                  80.663902         0.452853
# 11       161       13     97              34        85           0.400000  74.411765       19.516125            222.700485                  98.527145         0.442420
# 12        26        0     95              33        96           0.343750  70.606061       19.490901            244.511383                  99.924286         0.408669
# 13       265       43     98              32        56           0.571429  70.218750       19.422529            128.848114                  78.173309         0.606709
# 14       203       24     88              32        65           0.492308  74.156250       19.393313            169.483978                  57.924469         0.341770
# 15       234       32     84              31        53           0.584906  73.741935       19.439232            129.517212                  53.724930         0.414809
# 16       117        4     76              31        73           0.424658  69.322581       19.414812            223.157776                 100.792580         0.451665
# 17       216       31     78              29        48           0.604167  57.620690       19.348669             81.601036                  50.969402         0.624617
# 18       226       39     99              29        61           0.475410  36.965517       19.160405            138.166946                  40.797291         0.295275
# 19       184       20     81              29        62           0.467742  68.965517       19.514050            160.109009                  18.240580         0.113926
# 20         5        0     69              29        70           0.414286  72.724138       19.411343            202.373276                 113.216270         0.559443
# 21        29        0     40              28        41           0.682927  52.392857       19.195571            112.115585                  29.477631         0.262922
# 22       291       46     99              28        54           0.518519  70.428571       19.228962            110.540359                  61.435154         0.555771
# 23       174       29     96              27        68           0.397059  48.148148       19.316519             87.782974                  26.763212         0.304879
# 24       171       23     97              27        75           0.360000  46.925926       19.174860            196.210999                 104.670692         0.533460
# 25       155       12     91              27        80           0.337500  58.074074       19.415710            255.585938                  32.055161         0.125418
# 26        70        3     99              27        97           0.278351  49.629630       19.369381            203.495300                  22.811579         0.112099
# 27       170       16     66              26        51           0.509804  42.769231       19.255624            115.974304                  74.521133         0.642566
# 28       240       39     95              26        57           0.456140  76.538462       19.525508            160.424698                  87.909721         0.547981
# 29       145       14     96              26        83           0.313253  61.230769       19.290464            197.061493                  51.548946         0.261588
# Ch37: 4722 nodes, 435 tracks

# %% [markdown]
# ## 8. Combine multi-sample artifacts

# %%
def concat_or_empty(frames):
    return (
        pd.concat(frames, ignore_index=True)
        if frames
        else pd.DataFrame()
    )


combined_outputs = {
    "chapter34_top200_detections_multisample.csv":
        concat_or_empty(CH34_ALL),

    "chapter35_track_nodes_multisample.csv":
        concat_or_empty(CH35_NODES_ALL),

    "chapter35_track_edges_multisample.csv":
        concat_or_empty(CH35_EDGES_ALL),

    "chapter35_track_summary_multisample.csv":
        concat_or_empty(CH35_SUMMARY_ALL),

    "chapter36_filtered_detections_multisample.csv":
        concat_or_empty(CH36_DET_ALL),

    "chapter36_filtered_track_nodes_multisample.csv":
        concat_or_empty(CH36_NODES_ALL),

    "chapter36_filtered_track_edges_multisample.csv":
        concat_or_empty(CH36_EDGES_ALL),

    "chapter37_refined_track_nodes_multisample.csv":
        concat_or_empty(CH37_NODES_ALL),

    "chapter37_refined_track_edges_multisample.csv":
        concat_or_empty(CH37_EDGES_ALL),

    "chapter37_refined_track_summary_multisample.csv":
        concat_or_empty(CH37_SUMMARY_ALL),
}

for filename, df in combined_outputs.items():
    path = CONFIG.output_dir / filename
    df.to_csv(path, index=False)
    print(f"{filename}: {len(df):,} rows")
# Out:
# chapter34_top200_detections_multisample.csv: 60,000 rows
# chapter35_track_nodes_multisample.csv: 60,000 rows
# chapter35_track_edges_multisample.csv: 52,849 rows
# chapter35_track_summary_multisample.csv: 7,151 rows
# chapter36_filtered_detections_multisample.csv: 15,000 rows
# chapter36_filtered_track_nodes_multisample.csv: 15,000 rows
# chapter36_filtered_track_edges_multisample.csv: 7,821 rows
# chapter37_refined_track_nodes_multisample.csv: 13,892 rows
# chapter37_refined_track_edges_multisample.csv: 8,949 rows
# chapter37_refined_track_summary_multisample.csv: 1,347 rows

# %% [markdown]
# ## 9. Required per-sample summary and explicit validation

# %%
sample_summary_df = pd.DataFrame(SAMPLE_SUMMARY)
validation_df = pd.DataFrame(VALIDATION)
failures_df = pd.DataFrame(FAILURES)

sample_summary_df.to_csv(
    CONFIG.output_dir / "chapter46a_sample_summary.csv",
    index=False,
)
validation_df.to_csv(
    CONFIG.output_dir / "chapter46a_validation.csv",
    index=False,
)
failures_df.to_csv(
    CONFIG.output_dir / "chapter46a_failures.csv",
    index=False,
)

print("Per-sample summary:")
display(sample_summary_df)

print("\nValidation:")
display(validation_df)

if len(failures_df):
    print("\nFailures:")
    display(
        failures_df[
            ["sample_id", "stage", "error_type", "message"]
        ]
    )
else:
    print("\nNo stage failures recorded.")
# Out:
# Per-sample summary:
#        sample_id  gt_binary_divisions  ch34_rows  ch36_rows  ch37_nodes  ch37_track_count
# 0  6bba_48816121                    5      20000       5000        4574               504
# 1  6bba_09961292                    4      20000       5000        4596               408
# 2  6bba_afb141ff                    4      20000       5000        4722               435
# Validation:
#        sample_id  gt_binary_divisions  ch34_ok  ch35_ok  ch36_ok  ch37_ok                             filter_mode final_status
# 0  6bba_48816121                    5     True     True     True     True  historical_label_free_temporal_support     COMPLETE
# 1  6bba_09961292                    4     True     True     True     True  historical_label_free_temporal_support     COMPLETE
# 2  6bba_afb141ff                    4     True     True     True     True  historical_label_free_temporal_support     COMPLETE
# No stage failures recorded.

# %%
required_tables = {
    "ch34":
        combined_outputs[
            "chapter34_top200_detections_multisample.csv"
        ],
    "ch35_nodes":
        combined_outputs[
            "chapter35_track_nodes_multisample.csv"
        ],
    "ch35_edges":
        combined_outputs[
            "chapter35_track_edges_multisample.csv"
        ],
    "ch36":
        combined_outputs[
            "chapter36_filtered_detections_multisample.csv"
        ],
    "ch37_nodes":
        combined_outputs[
            "chapter37_refined_track_nodes_multisample.csv"
        ],
    "ch37_edges":
        combined_outputs[
            "chapter37_refined_track_edges_multisample.csv"
        ],
}

selected_ids = set(
    selected_samples["sample_id"].astype(str)
)

coverage_rows = []

for sample_id in sorted(selected_ids):
    row = {"sample_id": sample_id}

    for stage_name, df in required_tables.items():
        present = (
            (not df.empty)
            and ("sample_id" in df.columns)
            and (
                df["sample_id"]
                .astype(str)
                .eq(sample_id)
                .any()
            )
        )
        row[f"{stage_name}_present"] = bool(present)

    presence_flags = [
        v
        for k, v in row.items()
        if k.endswith("_present")
    ]
    row["all_required_artifacts_present"] = all(
        presence_flags
    )
    coverage_rows.append(row)

coverage_df = pd.DataFrame(coverage_rows)
coverage_df.to_csv(
    CONFIG.output_dir / "chapter46a_artifact_coverage.csv",
    index=False,
)

display(coverage_df)

missing = coverage_df[
    ~coverage_df["all_required_artifacts_present"]
]

if len(missing):
    print(
        f"INCOMPLETE: {len(missing)} selected samples are "
        "missing at least one required downstream artifact."
    )
else:
    print(
        f"COMPLETE: all {len(selected_ids)} selected samples "
        "appear in every required downstream artifact."
    )
# Out:
#        sample_id  ch34_present  ch35_nodes_present  ch35_edges_present  ch36_present  ch37_nodes_present  ch37_edges_present  all_required_artifacts_present
# 0  6bba_09961292          True                True                True          True                True                True                            True
# 1  6bba_48816121          True                True                True          True                True                True                            True
# 2  6bba_afb141ff          True                True                True          True                True                True                            True
# COMPLETE: all 3 selected samples appear in every required downstream artifact.

# %% [markdown]
# ## 10. Package the generated artifacts

# %%
zip_path = (
    CONFIG.output_dir
    / "chapter46a_multisample_pipeline_artifacts.zip"
)

csv_paths = sorted(
    CONFIG.output_dir.glob("*.csv")
)

with zipfile.ZipFile(
    zip_path,
    "w",
    compression=zipfile.ZIP_DEFLATED,
) as zf:
    for path in csv_paths:
        zf.write(path, arcname=path.name)

run_manifest = {
    "selected_sample_count": int(len(selected_samples)),
    "complete_sample_count": int(
        validation_df["final_status"]
        .eq("COMPLETE")
        .sum()
        if "final_status" in validation_df.columns
        else 0
    ),
    "failure_count": int(len(failures_df)),
    "historical_sample_id": CONFIG.historical_sample_id,
    "strict_complete": CONFIG.strict_complete,
    "package": str(zip_path),
}

with (
    CONFIG.output_dir
    / "chapter46a_run_manifest.json"
).open("w") as f:
    json.dump(run_manifest, f, indent=2)

print("Saved:", zip_path)
print(json.dumps(run_manifest, indent=2))
# Out:
# Saved: /kaggle/working/chapter46a/chapter46a_multisample_pipeline_artifacts.zip
# {
#   "selected_sample_count": 3,
#   "complete_sample_count": 3,
#   "failure_count": 0,
#   "historical_sample_id": "44b6_12dfb391",
#   "strict_complete": false,
#   "package": "/kaggle/working/chapter46a/chapter46a_multisample_pipeline_artifacts.zip"
# }

# %% [markdown]
# ## 11. Completion gate
#
# Chapter 46A is complete only when:
#
# - multiple selected samples contain binary GT divisions;
# - every selected sample reaches Chapter 37;
# - every required combined artifact contains `sample_id`;
# - tracks are generated independently per sample and receive globally-qualified IDs before concatenation;
# - no failed sample is hidden;
# - the required summary is populated;
# - `chapter46a_multisample_pipeline_artifacts.zip` exists.
#
# Once this gate passes, point the existing Chapter 46 audit at the generated multi-sample Chapter 34, Chapter 36, and Chapter 37 CSVs.

# %%
complete_count = int(
    validation_df["final_status"].eq("COMPLETE").sum()
    if "final_status" in validation_df.columns
    else 0
)

print(
    f"Chapter 46A V12 mini-batch complete samples: "
    f"{complete_count}/{len(selected_samples)}"
)

if complete_count == len(selected_samples) and complete_count == 3:
    print("\n✓ V12 THREE-SAMPLE MINI-BATCH PASSED.")
    print(
        "All three selected samples reached Chapter 37. "
        "The reproduction harness is now ready for a larger cohort run."
    )
elif complete_count == len(selected_samples) and complete_count > 0:
    print("\n✓ SELECTED MINI-BATCH PASSED.")
    print(
        "All selected samples reached Chapter 37, but verify that "
        "CONFIG.max_selected_samples is 3 before scaling."
    )
else:
    print("\n⚠ V12 MINI-BATCH DID NOT FULLY PASS.")
    print(
        "Do NOT scale to the full cohort. Inspect chapter46a_failures.csv. "
        "Completed stage CSVs can be reused on a rerun in the same Kaggle workspace."
    )

print(
    "\nV12 uses per-stage checkpoint reuse and does not raise a final "
    "RuntimeError solely because one sample failed."
)
# Out:
# Chapter 46A V12 mini-batch complete samples: 3/3
#
# ✓ V12 THREE-SAMPLE MINI-BATCH PASSED.
# All three selected samples reached Chapter 37. The reproduction harness is now ready for a larger cohort run.
#
# V12 uses per-stage checkpoint reuse and does not raise a final RuntimeError solely because one sample failed.
